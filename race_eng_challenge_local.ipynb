# %% [markdown]
# # Set Up Environment

# %% [markdown]
# ## Create a virtual python environment to use as the kernel (using VS code)
#
# Run the following in the terminal (for Windows):
# - python -m venv .venv
# - .venv\Scripts\activate
# - python.exe -m pip install --upgrade pip
# - pip install -r requirements.txt
# - deactivate (to exit the venv)
#
# If uisng VSCode, you should now be able to selct the .venv as the kernel to run the python notebook in.
#
# ![alt text](images/RaceEngChallenge/image.png)

# %% [markdown]
# ## Set the path and import required dependencies

# %%
import logging
import nest_asyncio

logging.basicConfig(level=logging.INFO)
nest_asyncio.apply()

import os
import sys

# Get the directory of the current script
script_dir = os.path.dirname(os.getcwd())

# Define the relative path (e.g., parent directory's src)
relative_path = os.path.join('..', 'src')

# Convert the relative path to an absolute path
absolute_path = os.path.abspath(os.path.join(script_dir, relative_path))

# Add the absolute path to sys.path
sys.path.insert(0, absolute_path)

from src.RaceEngChallenge import *

# %% [markdown]
# ## Authenticate
#
# Run this to authenticate yourself with the canopy sims API. There will be a keyboard entry prompt displayed.
#
# ![alt text](images/RaceEngChallenge/image-1.png)
#
# ![alt text](images/RaceEngChallenge/image-2.png)
#
# ![alt text](images/RaceEngChallenge/image-3.png)
#
# ![alt text](images/RaceEngChallenge/image-4.png)
#
# If the credentials are correct and authentication is successful, you will see:
#
# ![alt text](images/RaceEngChallenge/image-5.png)

# %%
session = await authenticate_canopy_sims_api(canopy.prompt_for_authentication())
user_id = session.authentication.user_id
# Out:
# Authenticated successfully!

# %% [markdown]
# # Start of script
#
# ## Inputs

# %%
# Enter sim_version
sim_version = '1.12300'
# Put your worksheet ID here. This canbe fouhnd in the URL of the worksheet: https://portal.canopysimulations.com/worksheets/client_id/worksheet_id
worksheet_id = '009d393737b04d2c8ab69553ee50e102'
# Enter the worksheet row names from which we extract the car configurations from. These rows will not be modified.
source_row_names = [
    'base'
]

# %% [markdown]
# ## Run this to reset the worksheet

# %% [markdown]
# The following block can be called if you need to clean all the rows of the worksheet, except for those specified in the row_names list.

# %%
#  First, reset the worksheet to only contain the rows we want to modify
reset_worksheet_result = await reset_worksheet(
    session=session,
    worksheet_id=worksheet_id,
    row_names=source_row_names
)

# %% [markdown]
# ## Setup explorations
#
# ### Swept parameters and scalar limits
#
# For this challenge, the objective is to identify the fastest legal car by varying certian parameters listed below, given a set of constraints. We will start with some fundamental parameters to be swept first.
#
# The scalar limits must be adhered to by the identified car, else, the car is deemed to be illegal. Note that tLapTotal is also specified as a scalar limit with a max value of the lap time in the baseline configuration.. This is because it's quite a convenient way to introduce it into the function so that any cars slower than the baseline car are rejected.
#
# Run the cell below to setup these parameters and limits.

# %%
swept_param_paths = [
    'car.chassis.hRideFSetup',
    'car.chassis.hRideRSetup',
    'car.aero.flapAngles.aFlapF',
    'car.suspension.front.internal.antiRollBar.kAntiRollBar',
    'car.suspension.rear.internal.antiRollBar.kAntiRollBar',
    'car.suspension.front.internal.torsionBar.kTorsionBar',
    'car.suspension.rear.internal.triSpring.kSpring',
    'car.chassis.carRunningMass.rWeightBalF',
    'car.suspension.front.external.aCamberSetupAlignment.aCamberSetup',
    'car.suspension.rear.external.aCamberSetupAlignment.aCamberSetup',
    # 'car.powertrain.rearAxleTransmission.diff.MDiffDemandOutputs[0]',
    # 'car.powertrain.rearAxleTransmission.diff.MDiffDemandOutputs[2]',
    # 'car.control.brakeBalanceOptimisation.mapOutput.values[0]',
    # 'car.control.brakeBalanceOptimisation.mapOutput.values[1]',
    # 'car.control.brakeBalanceOptimisation.mapOutput.values[2]',
    # 'car.control.brakeBalanceOptimisation.mapOutput.values[3]',
    # 'car.control.brakeBalanceOptimisation.mapOutput.values[4]',
    # 'car.control.brakeBalanceOptimisation.mapOutput.values[5]',
    # 'car.control.brakeBalanceOptimisation.mapOutput.values[6]',
    # 'car.control.brakeBalanceOptimisation.mapOutput.values[7]',
    # 'car.control.brakeBalanceOptimisation.mapOutput.values[8]',
]

swept_parameter_data = [
    { 
        'id': 'hRideFSetup',
        'path': 'car.chassis.hRideFSetup',
        'min': 0.01,
        'max': 0.05
    },
    {
        'id': 'hRideRSetup',
        'path': 'car.chassis.hRideRSetup',
        'min': 0.01,
        'max': 0.08
    },
    {
        'id': 'aFlapF',
        'path': 'car.aero.flapAngles.aFlapF',
        'min': 0.4,
        'max': 1.0
    },
    {
        'id':'rWeightBalF',
        'path':'car.chassis.carRunningMass.rWeightBalF',
        'min': 0.45,
        'max': 0.47
    },
    {
        'id':'aCamberSetupF',
        'path':'car.suspension.front.external.aCamberSetupAlignment.aCamberSetup',
        'min': -0.1,
        'max': 0.0
    },
    {
        'id':'aCamberSetupR',
        'path':'car.suspension.rear.external.aCamberSetupAlignment.aCamberSetup',
        'min': -0.1,
        'max': 0.0
    },
    # {
    #     'id': 'kAntiRollBarF',
    #     'path': 'car.suspension.front.internal.antiRollBar.kAntiRollBar',
    #     'min': 0.0,
    #     'max': 100000.0
    # },
    # {
    #     'id': 'kAntiRollBarR',
    #     'path': 'car.suspension.rear.internal.antiRollBar.kAntiRollBar',
    #     'min': 0.0,
    #     'max': 100000.0
    # },
    # {
    #     'id': 'kTorsionBarF',
    #     'path': 'car.suspension.front.internal.torsionBar.kTorsionBar',
    #     'min': 0.0,
    #     'max': 10000.0
    # },
    # {
    #     'id': 'kTorsionBarR',
    #     'path': 'car.suspension.rear.internal.triSpring.kSpring',
    #     'min': 0.0,
    #     'max': 10000.0
    # }
]


dynamic_lap_scalar_limits = [
    {
        'id':'RaceEng_EBottoming',
        'max':0.5
    },
    {
        'id':'RaceEng_UndersteerT10Entry',
        'min':-4e-3,
    },
    {
        'id':'RaceEng_UndersteerT9',
        'min':-1.5e-3,
    },
    {
        'id':'RaceEng_aCamberFEOS',
        'min':-3.5,
        'max': 0.0
    },
    {
        'id':'RaceEng_aCamberREOS',
        'min':-1.5,
        'max': 0.0
    },
    {
        'id':'RaceEng_kHeaveF',
        'max':850000
    },
    {
        'id':'RaceEng_kHeaveR',
        'max':400000
    },
    {
        'id':'RaceEng_kRoll',
        'max':350000
    },
    {
        'id':'RaceEng_rBrakeBalHighPressure',
        'min':0.6
    },
    {
        'id':'tLapTotal',
        'min':0.0,
        'max':77.2468
    }
]

# %% [markdown]
# ## Check the scalar limits of the baseline study
#
# Now, check the baseline study in the worksheet by retrieving the job scalar data and identify if the baseline car is legal. As seen, the baseline car is legal.

# %%
study_id = '5ff167be3eac448cb83389c3a7d1ff15' # base study id

scalar_data = await get_scalar_data_from_jobs_in_study_with_id(
    session=session,
    study_id=study_id,
    sim_type='DynamicLap',
    scalar_limits=dynamic_lap_scalar_limits
)

# print(scalar_data)

disqualified_jobs_data = get_disqualified_jobs_data_in_study_with_id_due_to_scalar_limit_violations(
    scalar_data=scalar_data
)

print(f"Number of disqualified jobs: {len(disqualified_jobs_data)}")
# Out:
# INFO:canopy.load_study_job:Loading job index 0
# Number of disqualified jobs: 0

# %% [markdown]
# ## Run new study with a desired exploration
#
# Let's try a minimal heurisitcs incorporated approach to identify a faster car. One of the best ways to achieve this is to run some monte carlo explorations, whch we can setup and run the worksheet quite easily, following an approach shown in the cell below.

# %%
# Create a Monte Carlo exploration config
exploration_config_id = await create_monte_carlo_exploration_config_from_swept_parameter_data(
    session=session,
    name='exploration_mc_0',
    sim_version=sim_version,
    swept_parameter_data=swept_parameter_data,
    n_monte_carlo_points=1000
)

# print(exploration_config_id)

result = await run_worksheet_row_study_with_configs_having_ids(
    session=session,
    worksheet_id=worksheet_id,
    source_row_name='base',
    sim_version=sim_version,
    row_suffix='exploration_mc_0',
    config_ids=[exploration_config_id]
)

worksheet_row_name = result['worksheet_row_name']
study_id = result['study_id']
worksheet_id = result['worksheet_id']

# %% [markdown]
# ## Check if study with id is completed
#
# Run the cell below id identify if all the jobs in the study have completed. If completed, proceed to the next step.

# %%
# Comment this out if you run the cell above
study_id = '6f11e70e7f7745069d9e80f4e1b4435b'

study = await canopy.load_study(
    session=session,
    study_id=study_id,
)

print(f"study_state: {study.document.data['studyState']}")
# Out:
# study_state: completed

# %% [markdown]
# ## Re-check the scalar limits
#
# The cell below loads the scalar data of all the jobs in the study and can take some time, especially for a Monte Carlo exploration with 100s of sims.
#
# The warnings that are displayed are caused by jobs which have failed.
#
# ![alt text](images/RaceEngChallenge/image-6.png)
#
# ![alt text](images/RaceEngChallenge/image-7.png)

# %%
scalar_data = await get_scalar_data_from_jobs_in_study_with_id(
    session=session,
    study_id=study_id,
    sim_type='DynamicLap',
    scalar_limits=dynamic_lap_scalar_limits
)

# print(scalar_data)
# Out:
# INFO:canopy.load_study_job:Loading job index 0
# INFO:canopy.load_study_job:Loading job index 1
# INFO:canopy.load_study_job:Loading job index 2
# INFO:canopy.load_study_job:Loading job index 3
# INFO:canopy.load_study_job:Loading job index 4
# WARNING:canopy.request_with_retry:Retrying https://api.canopysimulations.com/studies/a4ed02d5506c4237a58d520e151f74be/6f11e70e7f7745069d9e80f4e1b4435b/jobs/4/metadata
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 5
# INFO:canopy.load_study_job:Loading job index 6
# INFO:canopy.load_study_job:Loading job index 7
# INFO:canopy.load_study_job:Loading job index 8
# INFO:canopy.load_study_job:Loading job index 9
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 10
# INFO:canopy.load_study_job:Loading job index 11
# INFO:canopy.load_study_job:Loading job index 12
# INFO:canopy.load_study_job:Loading job index 13
# INFO:canopy.load_study_job:Loading job index 14
# INFO:canopy.load_study_job:Loading job index 15
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 16
# INFO:canopy.load_study_job:Loading job index 17
# INFO:canopy.load_study_job:Loading job index 18
# INFO:canopy.load_study_job:Loading job index 19
# INFO:canopy.load_study_job:Loading job index 20
# INFO:canopy.load_study_job:Loading job index 21
# INFO:canopy.load_study_job:Loading job index 22
# INFO:canopy.load_study_job:Loading job index 23
# INFO:canopy.load_study_job:Loading job index 24
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 25
# INFO:canopy.load_study_job:Loading job index 26
# INFO:canopy.load_study_job:Loading job index 27
# INFO:canopy.load_study_job:Loading job index 28
# INFO:canopy.load_study_job:Loading job index 29
# INFO:canopy.load_study_job:Loading job index 30
# INFO:canopy.load_study_job:Loading job index 31
# INFO:canopy.load_study_job:Loading job index 32
# INFO:canopy.load_study_job:Loading job index 33
# INFO:canopy.load_study_job:Loading job index 34
# INFO:canopy.load_study_job:Loading job index 35
# INFO:canopy.load_study_job:Loading job index 36
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 37
# INFO:canopy.load_study_job:Loading job index 38
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 39
# INFO:canopy.load_study_job:Loading job index 40
# INFO:canopy.load_study_job:Loading job index 41
# INFO:canopy.load_study_job:Loading job index 42
# INFO:canopy.load_study_job:Loading job index 43
# INFO:canopy.load_study_job:Loading job index 44
# INFO:canopy.load_study_job:Loading job index 45
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 46
# INFO:canopy.load_study_job:Loading job index 47
# INFO:canopy.load_study_job:Loading job index 48
# INFO:canopy.load_study_job:Loading job index 49
# INFO:canopy.load_study_job:Loading job index 50
# INFO:canopy.load_study_job:Loading job index 51
# INFO:canopy.load_study_job:Loading job index 52
# INFO:canopy.load_study_job:Loading job index 53
# INFO:canopy.load_study_job:Loading job index 54
# INFO:canopy.load_study_job:Loading job index 55
# INFO:canopy.load_study_job:Loading job index 56
# INFO:canopy.load_study_job:Loading job index 57
# INFO:canopy.load_study_job:Loading job index 58
# INFO:canopy.load_study_job:Loading job index 59
# INFO:canopy.load_study_job:Loading job index 60
# INFO:canopy.load_study_job:Loading job index 61
# INFO:canopy.load_study_job:Loading job index 62
# INFO:canopy.load_study_job:Loading job index 63
# INFO:canopy.load_study_job:Loading job index 64
# INFO:canopy.load_study_job:Loading job index 65
# INFO:canopy.load_study_job:Loading job index 66
# INFO:canopy.load_study_job:Loading job index 67
# INFO:canopy.load_study_job:Loading job index 68
# INFO:canopy.load_study_job:Loading job index 69
# INFO:canopy.load_study_job:Loading job index 70
# INFO:canopy.load_study_job:Loading job index 71
# INFO:canopy.load_study_job:Loading job index 72
# INFO:canopy.load_study_job:Loading job index 73
# INFO:canopy.load_study_job:Loading job index 74
# INFO:canopy.load_study_job:Loading job index 75
# INFO:canopy.load_study_job:Loading job index 76
# INFO:canopy.load_study_job:Loading job index 77
# INFO:canopy.load_study_job:Loading job index 78
# INFO:canopy.load_study_job:Loading job index 79
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 80
# INFO:canopy.load_study_job:Loading job index 81
# INFO:canopy.load_study_job:Loading job index 82
# INFO:canopy.load_study_job:Loading job index 83
# INFO:canopy.load_study_job:Loading job index 84
# INFO:canopy.load_study_job:Loading job index 85
# INFO:canopy.load_study_job:Loading job index 86
# INFO:canopy.load_study_job:Loading job index 87
# INFO:canopy.load_study_job:Loading job index 88
# INFO:canopy.load_study_job:Loading job index 89
# INFO:canopy.load_study_job:Loading job index 90
# INFO:canopy.load_study_job:Loading job index 91
# INFO:canopy.load_study_job:Loading job index 92
# INFO:canopy.load_study_job:Loading job index 93
# INFO:canopy.load_study_job:Loading job index 94
# INFO:canopy.load_study_job:Loading job index 95
# INFO:canopy.load_study_job:Loading job index 96
# INFO:canopy.load_study_job:Loading job index 97
# INFO:canopy.load_study_job:Loading job index 98
# INFO:canopy.load_study_job:Loading job index 99
# INFO:canopy.load_study_job:Loading job index 100
# INFO:canopy.load_study_job:Loading job index 101
# INFO:canopy.load_study_job:Loading job index 102
# INFO:canopy.load_study_job:Loading job index 103
# INFO:canopy.load_study_job:Loading job index 104
# INFO:canopy.load_study_job:Loading job index 105
# INFO:canopy.load_study_job:Loading job index 106
# INFO:canopy.load_study_job:Loading job index 107
# INFO:canopy.load_study_job:Loading job index 108
# INFO:canopy.load_study_job:Loading job index 109
# INFO:canopy.load_study_job:Loading job index 110
# INFO:canopy.load_study_job:Loading job index 111
# INFO:canopy.load_study_job:Loading job index 112
# INFO:canopy.load_study_job:Loading job index 113
# INFO:canopy.load_study_job:Loading job index 114
# INFO:canopy.load_study_job:Loading job index 115
# INFO:canopy.load_study_job:Loading job index 116
# INFO:canopy.load_study_job:Loading job index 117
# INFO:canopy.load_study_job:Loading job index 118
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 119
# INFO:canopy.load_study_job:Loading job index 120
# INFO:canopy.load_study_job:Loading job index 121
# INFO:canopy.load_study_job:Loading job index 122
# INFO:canopy.load_study_job:Loading job index 123
# INFO:canopy.load_study_job:Loading job index 124
# INFO:canopy.load_study_job:Loading job index 125
# INFO:canopy.load_study_job:Loading job index 126
# INFO:canopy.load_study_job:Loading job index 127
# INFO:canopy.load_study_job:Loading job index 128
# INFO:canopy.load_study_job:Loading job index 129
# INFO:canopy.load_study_job:Loading job index 130
# INFO:canopy.load_study_job:Loading job index 131
# INFO:canopy.load_study_job:Loading job index 132
# INFO:canopy.load_study_job:Loading job index 133
# INFO:canopy.load_study_job:Loading job index 134
# INFO:canopy.load_study_job:Loading job index 135
# INFO:canopy.load_study_job:Loading job index 136
# INFO:canopy.load_study_job:Loading job index 137
# INFO:canopy.load_study_job:Loading job index 138
# INFO:canopy.load_study_job:Loading job index 139
# INFO:canopy.load_study_job:Loading job index 140
# INFO:canopy.load_study_job:Loading job index 141
# INFO:canopy.load_study_job:Loading job index 142
# INFO:canopy.load_study_job:Loading job index 143
# INFO:canopy.load_study_job:Loading job index 144
# INFO:canopy.load_study_job:Loading job index 145
# INFO:canopy.load_study_job:Loading job index 146
# INFO:canopy.load_study_job:Loading job index 147
# INFO:canopy.load_study_job:Loading job index 148
# INFO:canopy.load_study_job:Loading job index 149
# INFO:canopy.load_study_job:Loading job index 150
# INFO:canopy.load_study_job:Loading job index 151
# INFO:canopy.load_study_job:Loading job index 152
# INFO:canopy.load_study_job:Loading job index 153
# INFO:canopy.load_study_job:Loading job index 154
# INFO:canopy.load_study_job:Loading job index 155
# INFO:canopy.load_study_job:Loading job index 156
# INFO:canopy.load_study_job:Loading job index 157
# INFO:canopy.load_study_job:Loading job index 158
# INFO:canopy.load_study_job:Loading job index 159
# INFO:canopy.load_study_job:Loading job index 160
# INFO:canopy.load_study_job:Loading job index 161
# INFO:canopy.load_study_job:Loading job index 162
# INFO:canopy.load_study_job:Loading job index 163
# INFO:canopy.load_study_job:Loading job index 164
# INFO:canopy.load_study_job:Loading job index 165
# INFO:canopy.load_study_job:Loading job index 166
# INFO:canopy.load_study_job:Loading job index 167
# INFO:canopy.load_study_job:Loading job index 168
# INFO:canopy.load_study_job:Loading job index 169
# INFO:canopy.load_study_job:Loading job index 170
# INFO:canopy.load_study_job:Loading job index 171
# INFO:canopy.load_study_job:Loading job index 172
# INFO:canopy.load_study_job:Loading job index 173
# INFO:canopy.load_study_job:Loading job index 174
# INFO:canopy.load_study_job:Loading job index 175
# INFO:canopy.load_study_job:Loading job index 176
# INFO:canopy.load_study_job:Loading job index 177
# INFO:canopy.load_study_job:Loading job index 178
# INFO:canopy.load_study_job:Loading job index 179
# INFO:canopy.load_study_job:Loading job index 180
# INFO:canopy.load_study_job:Loading job index 181
# INFO:canopy.load_study_job:Loading job index 182
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 183
# INFO:canopy.load_study_job:Loading job index 184
# INFO:canopy.load_study_job:Loading job index 185
# INFO:canopy.load_study_job:Loading job index 186
# INFO:canopy.load_study_job:Loading job index 187
# INFO:canopy.load_study_job:Loading job index 188
# INFO:canopy.load_study_job:Loading job index 189
# INFO:canopy.load_study_job:Loading job index 190
# INFO:canopy.load_study_job:Loading job index 191
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 192
# INFO:canopy.load_study_job:Loading job index 193
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 194
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 195
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 196
# INFO:canopy.load_study_job:Loading job index 197
# INFO:canopy.load_study_job:Loading job index 198
# INFO:canopy.load_study_job:Loading job index 199
# INFO:canopy.load_study_job:Loading job index 200
# INFO:canopy.load_study_job:Loading job index 201
# INFO:canopy.load_study_job:Loading job index 202
# INFO:canopy.load_study_job:Loading job index 203
# INFO:canopy.load_study_job:Loading job index 204
# INFO:canopy.load_study_job:Loading job index 205
# INFO:canopy.load_study_job:Loading job index 206
# INFO:canopy.load_study_job:Loading job index 207
# INFO:canopy.load_study_job:Loading job index 208
# INFO:canopy.load_study_job:Loading job index 209
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 210
# INFO:canopy.load_study_job:Loading job index 211
# INFO:canopy.load_study_job:Loading job index 212
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 213
# INFO:canopy.load_study_job:Loading job index 214
# INFO:canopy.load_study_job:Loading job index 215
# INFO:canopy.load_study_job:Loading job index 216
# INFO:canopy.load_study_job:Loading job index 217
# INFO:canopy.load_study_job:Loading job index 218
# INFO:canopy.load_study_job:Loading job index 219
# INFO:canopy.load_study_job:Loading job index 220
# INFO:canopy.load_study_job:Loading job index 221
# INFO:canopy.load_study_job:Loading job index 222
# INFO:canopy.load_study_job:Loading job index 223
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 224
# INFO:canopy.load_study_job:Loading job index 225
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 226
# INFO:canopy.load_study_job:Loading job index 227
# INFO:canopy.load_study_job:Loading job index 228
# INFO:canopy.load_study_job:Loading job index 229
# INFO:canopy.load_study_job:Loading job index 230
# INFO:canopy.load_study_job:Loading job index 231
# INFO:canopy.load_study_job:Loading job index 232
# INFO:canopy.load_study_job:Loading job index 233
# INFO:canopy.load_study_job:Loading job index 234
# INFO:canopy.load_study_job:Loading job index 235
# INFO:canopy.load_study_job:Loading job index 236
# INFO:canopy.load_study_job:Loading job index 237
# INFO:canopy.load_study_job:Loading job index 238
# INFO:canopy.load_study_job:Loading job index 239
# INFO:canopy.load_study_job:Loading job index 240
# INFO:canopy.load_study_job:Loading job index 241
# INFO:canopy.load_study_job:Loading job index 242
# INFO:canopy.load_study_job:Loading job index 243
# INFO:canopy.load_study_job:Loading job index 244
# INFO:canopy.load_study_job:Loading job index 245
# INFO:canopy.load_study_job:Loading job index 246
# INFO:canopy.load_study_job:Loading job index 247
# INFO:canopy.load_study_job:Loading job index 248
# INFO:canopy.load_study_job:Loading job index 249
# INFO:canopy.load_study_job:Loading job index 250
# INFO:canopy.load_study_job:Loading job index 251
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 252
# INFO:canopy.load_study_job:Loading job index 253
# INFO:canopy.load_study_job:Loading job index 254
# INFO:canopy.load_study_job:Loading job index 255
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 256
# INFO:canopy.load_study_job:Loading job index 257
# INFO:canopy.load_study_job:Loading job index 258
# INFO:canopy.load_study_job:Loading job index 259
# INFO:canopy.load_study_job:Loading job index 260
# INFO:canopy.load_study_job:Loading job index 261
# INFO:canopy.load_study_job:Loading job index 262
# INFO:canopy.load_study_job:Loading job index 263
# INFO:canopy.load_study_job:Loading job index 264
# INFO:canopy.load_study_job:Loading job index 265
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 266
# INFO:canopy.load_study_job:Loading job index 267
# INFO:canopy.load_study_job:Loading job index 268
# INFO:canopy.load_study_job:Loading job index 269
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 270
# INFO:canopy.load_study_job:Loading job index 271
# INFO:canopy.load_study_job:Loading job index 272
# INFO:canopy.load_study_job:Loading job index 273
# INFO:canopy.load_study_job:Loading job index 274
# INFO:canopy.load_study_job:Loading job index 275
# INFO:canopy.load_study_job:Loading job index 276
# INFO:canopy.load_study_job:Loading job index 277
# INFO:canopy.load_study_job:Loading job index 278
# INFO:canopy.load_study_job:Loading job index 279
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 280
# INFO:canopy.load_study_job:Loading job index 281
# INFO:canopy.load_study_job:Loading job index 282
# INFO:canopy.load_study_job:Loading job index 283
# INFO:canopy.load_study_job:Loading job index 284
# INFO:canopy.load_study_job:Loading job index 285
# INFO:canopy.load_study_job:Loading job index 286
# INFO:canopy.load_study_job:Loading job index 287
# INFO:canopy.load_study_job:Loading job index 288
# INFO:canopy.load_study_job:Loading job index 289
# INFO:canopy.load_study_job:Loading job index 290
# INFO:canopy.load_study_job:Loading job index 291
# INFO:canopy.load_study_job:Loading job index 292
# INFO:canopy.load_study_job:Loading job index 293
# INFO:canopy.load_study_job:Loading job index 294
# INFO:canopy.load_study_job:Loading job index 295
# INFO:canopy.load_study_job:Loading job index 296
# INFO:canopy.load_study_job:Loading job index 297
# INFO:canopy.load_study_job:Loading job index 298
# INFO:canopy.load_study_job:Loading job index 299
# INFO:canopy.load_study_job:Loading job index 300
# INFO:canopy.load_study_job:Loading job index 301
# INFO:canopy.load_study_job:Loading job index 302
# INFO:canopy.load_study_job:Loading job index 303
# INFO:canopy.load_study_job:Loading job index 304
# INFO:canopy.load_study_job:Loading job index 305
# INFO:canopy.load_study_job:Loading job index 306
# INFO:canopy.load_study_job:Loading job index 307
# INFO:canopy.load_study_job:Loading job index 308
# INFO:canopy.load_study_job:Loading job index 309
# INFO:canopy.load_study_job:Loading job index 310
# INFO:canopy.load_study_job:Loading job index 311
# INFO:canopy.load_study_job:Loading job index 312
# INFO:canopy.load_study_job:Loading job index 313
# INFO:canopy.load_study_job:Loading job index 314
# INFO:canopy.load_study_job:Loading job index 315
# INFO:canopy.load_study_job:Loading job index 316
# INFO:canopy.load_study_job:Loading job index 317
# INFO:canopy.load_study_job:Loading job index 318
# INFO:canopy.load_study_job:Loading job index 319
# INFO:canopy.load_study_job:Loading job index 320
# INFO:canopy.load_study_job:Loading job index 321
# INFO:canopy.load_study_job:Loading job index 322
# INFO:canopy.load_study_job:Loading job index 323
# INFO:canopy.load_study_job:Loading job index 324
# INFO:canopy.load_study_job:Loading job index 325
# INFO:canopy.load_study_job:Loading job index 326
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 327
# INFO:canopy.load_study_job:Loading job index 328
# INFO:canopy.load_study_job:Loading job index 329
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 330
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 331
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 332
# INFO:canopy.load_study_job:Loading job index 333
# INFO:canopy.load_study_job:Loading job index 334
# INFO:canopy.load_study_job:Loading job index 335
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 336
# INFO:canopy.load_study_job:Loading job index 337
# INFO:canopy.load_study_job:Loading job index 338
# INFO:canopy.load_study_job:Loading job index 339
# INFO:canopy.load_study_job:Loading job index 340
# INFO:canopy.load_study_job:Loading job index 341
# INFO:canopy.load_study_job:Loading job index 342
# INFO:canopy.load_study_job:Loading job index 343
# INFO:canopy.load_study_job:Loading job index 344
# INFO:canopy.load_study_job:Loading job index 345
# INFO:canopy.load_study_job:Loading job index 346
# INFO:canopy.load_study_job:Loading job index 347
# INFO:canopy.load_study_job:Loading job index 348
# INFO:canopy.load_study_job:Loading job index 349
# INFO:canopy.load_study_job:Loading job index 350
# INFO:canopy.load_study_job:Loading job index 351
# INFO:canopy.load_study_job:Loading job index 352
# INFO:canopy.load_study_job:Loading job index 353
# INFO:canopy.load_study_job:Loading job index 354
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 355
# INFO:canopy.load_study_job:Loading job index 356
# INFO:canopy.load_study_job:Loading job index 357
# INFO:canopy.load_study_job:Loading job index 358
# INFO:canopy.load_study_job:Loading job index 359
# INFO:canopy.load_study_job:Loading job index 360
# INFO:canopy.load_study_job:Loading job index 361
# INFO:canopy.load_study_job:Loading job index 362
# INFO:canopy.load_study_job:Loading job index 363
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 364
# INFO:canopy.load_study_job:Loading job index 365
# INFO:canopy.load_study_job:Loading job index 366
# INFO:canopy.load_study_job:Loading job index 367
# INFO:canopy.load_study_job:Loading job index 368
# INFO:canopy.load_study_job:Loading job index 369
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 370
# INFO:canopy.load_study_job:Loading job index 371
# INFO:canopy.load_study_job:Loading job index 372
# INFO:canopy.load_study_job:Loading job index 373
# INFO:canopy.load_study_job:Loading job index 374
# INFO:canopy.load_study_job:Loading job index 375
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 376
# INFO:canopy.load_study_job:Loading job index 377
# INFO:canopy.load_study_job:Loading job index 378
# INFO:canopy.load_study_job:Loading job index 379
# INFO:canopy.load_study_job:Loading job index 380
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 381
# INFO:canopy.load_study_job:Loading job index 382
# INFO:canopy.load_study_job:Loading job index 383
# INFO:canopy.load_study_job:Loading job index 384
# INFO:canopy.load_study_job:Loading job index 385
# INFO:canopy.load_study_job:Loading job index 386
# INFO:canopy.load_study_job:Loading job index 387
# INFO:canopy.load_study_job:Loading job index 388
# INFO:canopy.load_study_job:Loading job index 389
# INFO:canopy.load_study_job:Loading job index 390
# INFO:canopy.load_study_job:Loading job index 391
# INFO:canopy.load_study_job:Loading job index 392
# INFO:canopy.load_study_job:Loading job index 393
# INFO:canopy.load_study_job:Loading job index 394
# INFO:canopy.load_study_job:Loading job index 395
# INFO:canopy.load_study_job:Loading job index 396
# INFO:canopy.load_study_job:Loading job index 397
# INFO:canopy.load_study_job:Loading job index 398
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 399
# INFO:canopy.load_study_job:Loading job index 400
# INFO:canopy.load_study_job:Loading job index 401
# INFO:canopy.load_study_job:Loading job index 402
# INFO:canopy.load_study_job:Loading job index 403
# INFO:canopy.load_study_job:Loading job index 404
# INFO:canopy.load_study_job:Loading job index 405
# INFO:canopy.load_study_job:Loading job index 406
# INFO:canopy.load_study_job:Loading job index 407
# INFO:canopy.load_study_job:Loading job index 408
# INFO:canopy.load_study_job:Loading job index 409
# INFO:canopy.load_study_job:Loading job index 410
# INFO:canopy.load_study_job:Loading job index 411
# INFO:canopy.load_study_job:Loading job index 412
# INFO:canopy.load_study_job:Loading job index 413
# INFO:canopy.load_study_job:Loading job index 414
# INFO:canopy.load_study_job:Loading job index 415
# INFO:canopy.load_study_job:Loading job index 416
# INFO:canopy.load_study_job:Loading job index 417
# INFO:canopy.load_study_job:Loading job index 418
# INFO:canopy.load_study_job:Loading job index 419
# INFO:canopy.load_study_job:Loading job index 420
# INFO:canopy.load_study_job:Loading job index 421
# INFO:canopy.load_study_job:Loading job index 422
# INFO:canopy.load_study_job:Loading job index 423
# INFO:canopy.load_study_job:Loading job index 424
# INFO:canopy.load_study_job:Loading job index 425
# INFO:canopy.load_study_job:Loading job index 426
# INFO:canopy.load_study_job:Loading job index 427
# INFO:canopy.load_study_job:Loading job index 428
# INFO:canopy.load_study_job:Loading job index 429
# INFO:canopy.load_study_job:Loading job index 430
# INFO:canopy.load_study_job:Loading job index 431
# INFO:canopy.load_study_job:Loading job index 432
# INFO:canopy.load_study_job:Loading job index 433
# INFO:canopy.load_study_job:Loading job index 434
# INFO:canopy.load_study_job:Loading job index 435
# INFO:canopy.load_study_job:Loading job index 436
# INFO:canopy.load_study_job:Loading job index 437
# INFO:canopy.load_study_job:Loading job index 438
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 439
# INFO:canopy.load_study_job:Loading job index 440
# INFO:canopy.load_study_job:Loading job index 441
# INFO:canopy.load_study_job:Loading job index 442
# INFO:canopy.load_study_job:Loading job index 443
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 444
# INFO:canopy.load_study_job:Loading job index 445
# INFO:canopy.load_study_job:Loading job index 446
# INFO:canopy.load_study_job:Loading job index 447
# INFO:canopy.load_study_job:Loading job index 448
# INFO:canopy.load_study_job:Loading job index 449
# INFO:canopy.load_study_job:Loading job index 450
# INFO:canopy.load_study_job:Loading job index 451
# INFO:canopy.load_study_job:Loading job index 452
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 453
# INFO:canopy.load_study_job:Loading job index 454
# INFO:canopy.load_study_job:Loading job index 455
# INFO:canopy.load_study_job:Loading job index 456
# INFO:canopy.load_study_job:Loading job index 457
# INFO:canopy.load_study_job:Loading job index 458
# INFO:canopy.load_study_job:Loading job index 459
# INFO:canopy.load_study_job:Loading job index 460
# INFO:canopy.load_study_job:Loading job index 461
# INFO:canopy.load_study_job:Loading job index 462
# INFO:canopy.load_study_job:Loading job index 463
# INFO:canopy.load_study_job:Loading job index 464
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 465
# INFO:canopy.load_study_job:Loading job index 466
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 467
# INFO:canopy.load_study_job:Loading job index 468
# INFO:canopy.load_study_job:Loading job index 469
# INFO:canopy.load_study_job:Loading job index 470
# INFO:canopy.load_study_job:Loading job index 471
# INFO:canopy.load_study_job:Loading job index 472
# INFO:canopy.load_study_job:Loading job index 473
# INFO:canopy.load_study_job:Loading job index 474
# INFO:canopy.load_study_job:Loading job index 475
# INFO:canopy.load_study_job:Loading job index 476
# INFO:canopy.load_study_job:Loading job index 477
# INFO:canopy.load_study_job:Loading job index 478
# INFO:canopy.load_study_job:Loading job index 479
# INFO:canopy.load_study_job:Loading job index 480
# INFO:canopy.load_study_job:Loading job index 481
# INFO:canopy.load_study_job:Loading job index 482
# INFO:canopy.load_study_job:Loading job index 483
# INFO:canopy.load_study_job:Loading job index 484
# INFO:canopy.load_study_job:Loading job index 485
# INFO:canopy.load_study_job:Loading job index 486
# INFO:canopy.load_study_job:Loading job index 487
# INFO:canopy.load_study_job:Loading job index 488
# INFO:canopy.load_study_job:Loading job index 489
# INFO:canopy.load_study_job:Loading job index 490
# INFO:canopy.load_study_job:Loading job index 491
# INFO:canopy.load_study_job:Loading job index 492
# INFO:canopy.load_study_job:Loading job index 493
# INFO:canopy.load_study_job:Loading job index 494
# INFO:canopy.load_study_job:Loading job index 495
# INFO:canopy.load_study_job:Loading job index 496
# INFO:canopy.load_study_job:Loading job index 497
# INFO:canopy.load_study_job:Loading job index 498
# INFO:canopy.load_study_job:Loading job index 499
# INFO:canopy.load_study_job:Loading job index 500
# INFO:canopy.load_study_job:Loading job index 501
# INFO:canopy.load_study_job:Loading job index 502
# INFO:canopy.load_study_job:Loading job index 503
# INFO:canopy.load_study_job:Loading job index 504
# INFO:canopy.load_study_job:Loading job index 505
# INFO:canopy.load_study_job:Loading job index 506
# INFO:canopy.load_study_job:Loading job index 507
# INFO:canopy.load_study_job:Loading job index 508
# INFO:canopy.load_study_job:Loading job index 509
# INFO:canopy.load_study_job:Loading job index 510
# INFO:canopy.load_study_job:Loading job index 511
# INFO:canopy.load_study_job:Loading job index 512
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 513
# INFO:canopy.load_study_job:Loading job index 514
# INFO:canopy.load_study_job:Loading job index 515
# INFO:canopy.load_study_job:Loading job index 516
# INFO:canopy.load_study_job:Loading job index 517
# INFO:canopy.load_study_job:Loading job index 518
# INFO:canopy.load_study_job:Loading job index 519
# INFO:canopy.load_study_job:Loading job index 520
# INFO:canopy.load_study_job:Loading job index 521
# INFO:canopy.load_study_job:Loading job index 522
# INFO:canopy.load_study_job:Loading job index 523
# INFO:canopy.load_study_job:Loading job index 524
# INFO:canopy.load_study_job:Loading job index 525
# INFO:canopy.load_study_job:Loading job index 526
# INFO:canopy.load_study_job:Loading job index 527
# INFO:canopy.load_study_job:Loading job index 528
# INFO:canopy.load_study_job:Loading job index 529
# INFO:canopy.load_study_job:Loading job index 530
# INFO:canopy.load_study_job:Loading job index 531
# INFO:canopy.load_study_job:Loading job index 532
# INFO:canopy.load_study_job:Loading job index 533
# INFO:canopy.load_study_job:Loading job index 534
# INFO:canopy.load_study_job:Loading job index 535
# INFO:canopy.load_study_job:Loading job index 536
# INFO:canopy.load_study_job:Loading job index 537
# INFO:canopy.load_study_job:Loading job index 538
# INFO:canopy.load_study_job:Loading job index 539
# INFO:canopy.load_study_job:Loading job index 540
# INFO:canopy.load_study_job:Loading job index 541
# INFO:canopy.load_study_job:Loading job index 542
# INFO:canopy.load_study_job:Loading job index 543
# INFO:canopy.load_study_job:Loading job index 544
# INFO:canopy.load_study_job:Loading job index 545
# INFO:canopy.load_study_job:Loading job index 546
# INFO:canopy.load_study_job:Loading job index 547
# INFO:canopy.load_study_job:Loading job index 548
# INFO:canopy.load_study_job:Loading job index 549
# INFO:canopy.load_study_job:Loading job index 550
# INFO:canopy.load_study_job:Loading job index 551
# INFO:canopy.load_study_job:Loading job index 552
# INFO:canopy.load_study_job:Loading job index 553
# INFO:canopy.load_study_job:Loading job index 554
# INFO:canopy.load_study_job:Loading job index 555
# INFO:canopy.load_study_job:Loading job index 556
# INFO:canopy.load_study_job:Loading job index 557
# INFO:canopy.load_study_job:Loading job index 558
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 559
# INFO:canopy.load_study_job:Loading job index 560
# INFO:canopy.load_study_job:Loading job index 561
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 562
# INFO:canopy.load_study_job:Loading job index 563
# INFO:canopy.load_study_job:Loading job index 564
# INFO:canopy.load_study_job:Loading job index 565
# INFO:canopy.load_study_job:Loading job index 566
# INFO:canopy.load_study_job:Loading job index 567
# INFO:canopy.load_study_job:Loading job index 568
# INFO:canopy.load_study_job:Loading job index 569
# INFO:canopy.load_study_job:Loading job index 570
# INFO:canopy.load_study_job:Loading job index 571
# INFO:canopy.load_study_job:Loading job index 572
# INFO:canopy.load_study_job:Loading job index 573
# INFO:canopy.load_study_job:Loading job index 574
# INFO:canopy.load_study_job:Loading job index 575
# INFO:canopy.load_study_job:Loading job index 576
# INFO:canopy.load_study_job:Loading job index 577
# INFO:canopy.load_study_job:Loading job index 578
# INFO:canopy.load_study_job:Loading job index 579
# INFO:canopy.load_study_job:Loading job index 580
# INFO:canopy.load_study_job:Loading job index 581
# INFO:canopy.load_study_job:Loading job index 582
# INFO:canopy.load_study_job:Loading job index 583
# INFO:canopy.load_study_job:Loading job index 584
# INFO:canopy.load_study_job:Loading job index 585
# INFO:canopy.load_study_job:Loading job index 586
# INFO:canopy.load_study_job:Loading job index 587
# INFO:canopy.load_study_job:Loading job index 588
# INFO:canopy.load_study_job:Loading job index 589
# INFO:canopy.load_study_job:Loading job index 590
# INFO:canopy.load_study_job:Loading job index 591
# INFO:canopy.load_study_job:Loading job index 592
# INFO:canopy.load_study_job:Loading job index 593
# INFO:canopy.load_study_job:Loading job index 594
# INFO:canopy.load_study_job:Loading job index 595
# INFO:canopy.load_study_job:Loading job index 596
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 597
# INFO:canopy.load_study_job:Loading job index 598
# INFO:canopy.load_study_job:Loading job index 599
# INFO:canopy.load_study_job:Loading job index 600
# INFO:canopy.load_study_job:Loading job index 601
# INFO:canopy.load_study_job:Loading job index 602
# INFO:canopy.load_study_job:Loading job index 603
# INFO:canopy.load_study_job:Loading job index 604
# INFO:canopy.load_study_job:Loading job index 605
# INFO:canopy.load_study_job:Loading job index 606
# INFO:canopy.load_study_job:Loading job index 607
# INFO:canopy.load_study_job:Loading job index 608
# INFO:canopy.load_study_job:Loading job index 609
# INFO:canopy.load_study_job:Loading job index 610
# INFO:canopy.load_study_job:Loading job index 611
# INFO:canopy.load_study_job:Loading job index 612
# INFO:canopy.load_study_job:Loading job index 613
# INFO:canopy.load_study_job:Loading job index 614
# INFO:canopy.load_study_job:Loading job index 615
# INFO:canopy.load_study_job:Loading job index 616
# INFO:canopy.load_study_job:Loading job index 617
# INFO:canopy.load_study_job:Loading job index 618
# INFO:canopy.load_study_job:Loading job index 619
# INFO:canopy.load_study_job:Loading job index 620
# INFO:canopy.load_study_job:Loading job index 621
# INFO:canopy.load_study_job:Loading job index 622
# INFO:canopy.load_study_job:Loading job index 623
# INFO:canopy.load_study_job:Loading job index 624
# INFO:canopy.load_study_job:Loading job index 625
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 626
# INFO:canopy.load_study_job:Loading job index 627
# INFO:canopy.load_study_job:Loading job index 628
# INFO:canopy.load_study_job:Loading job index 629
# INFO:canopy.load_study_job:Loading job index 630
# INFO:canopy.load_study_job:Loading job index 631
# INFO:canopy.load_study_job:Loading job index 632
# INFO:canopy.load_study_job:Loading job index 633
# INFO:canopy.load_study_job:Loading job index 634
# INFO:canopy.load_study_job:Loading job index 635
# INFO:canopy.load_study_job:Loading job index 636
# INFO:canopy.load_study_job:Loading job index 637
# INFO:canopy.load_study_job:Loading job index 638
# INFO:canopy.load_study_job:Loading job index 639
# INFO:canopy.load_study_job:Loading job index 640
# INFO:canopy.load_study_job:Loading job index 641
# INFO:canopy.load_study_job:Loading job index 642
# INFO:canopy.load_study_job:Loading job index 643
# INFO:canopy.load_study_job:Loading job index 644
# INFO:canopy.load_study_job:Loading job index 645
# INFO:canopy.load_study_job:Loading job index 646
# INFO:canopy.load_study_job:Loading job index 647
# INFO:canopy.load_study_job:Loading job index 648
# INFO:canopy.load_study_job:Loading job index 649
# INFO:canopy.load_study_job:Loading job index 650
# INFO:canopy.load_study_job:Loading job index 651
# INFO:canopy.load_study_job:Loading job index 652
# INFO:canopy.load_study_job:Loading job index 653
# INFO:canopy.load_study_job:Loading job index 654
# INFO:canopy.load_study_job:Loading job index 655
# INFO:canopy.load_study_job:Loading job index 656
# INFO:canopy.load_study_job:Loading job index 657
# INFO:canopy.load_study_job:Loading job index 658
# INFO:canopy.load_study_job:Loading job index 659
# INFO:canopy.load_study_job:Loading job index 660
# INFO:canopy.load_study_job:Loading job index 661
# INFO:canopy.load_study_job:Loading job index 662
# INFO:canopy.load_study_job:Loading job index 663
# INFO:canopy.load_study_job:Loading job index 664
# INFO:canopy.load_study_job:Loading job index 665
# INFO:canopy.load_study_job:Loading job index 666
# INFO:canopy.load_study_job:Loading job index 667
# INFO:canopy.load_study_job:Loading job index 668
# INFO:canopy.load_study_job:Loading job index 669
# INFO:canopy.load_study_job:Loading job index 670
# INFO:canopy.load_study_job:Loading job index 671
# INFO:canopy.load_study_job:Loading job index 672
# INFO:canopy.load_study_job:Loading job index 673
# INFO:canopy.load_study_job:Loading job index 674
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 675
# INFO:canopy.load_study_job:Loading job index 676
# INFO:canopy.load_study_job:Loading job index 677
# INFO:canopy.load_study_job:Loading job index 678
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 679
# INFO:canopy.load_study_job:Loading job index 680
# INFO:canopy.load_study_job:Loading job index 681
# INFO:canopy.load_study_job:Loading job index 682
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 683
# INFO:canopy.load_study_job:Loading job index 684
# INFO:canopy.load_study_job:Loading job index 685
# INFO:canopy.load_study_job:Loading job index 686
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 687
# INFO:canopy.load_study_job:Loading job index 688
# INFO:canopy.load_study_job:Loading job index 689
# INFO:canopy.load_study_job:Loading job index 690
# INFO:canopy.load_study_job:Loading job index 691
# INFO:canopy.load_study_job:Loading job index 692
# INFO:canopy.load_study_job:Loading job index 693
# INFO:canopy.load_study_job:Loading job index 694
# INFO:canopy.load_study_job:Loading job index 695
# INFO:canopy.load_study_job:Loading job index 696
# INFO:canopy.load_study_job:Loading job index 697
# INFO:canopy.load_study_job:Loading job index 698
# INFO:canopy.load_study_job:Loading job index 699
# INFO:canopy.load_study_job:Loading job index 700
# INFO:canopy.load_study_job:Loading job index 701
# INFO:canopy.load_study_job:Loading job index 702
# INFO:canopy.load_study_job:Loading job index 703
# INFO:canopy.load_study_job:Loading job index 704
# INFO:canopy.load_study_job:Loading job index 705
# INFO:canopy.load_study_job:Loading job index 706
# INFO:canopy.load_study_job:Loading job index 707
# INFO:canopy.load_study_job:Loading job index 708
# INFO:canopy.load_study_job:Loading job index 709
# INFO:canopy.load_study_job:Loading job index 710
# INFO:canopy.load_study_job:Loading job index 711
# INFO:canopy.load_study_job:Loading job index 712
# INFO:canopy.load_study_job:Loading job index 713
# INFO:canopy.load_study_job:Loading job index 714
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 715
# INFO:canopy.load_study_job:Loading job index 716
# INFO:canopy.load_study_job:Loading job index 717
# INFO:canopy.load_study_job:Loading job index 718
# INFO:canopy.load_study_job:Loading job index 719
# INFO:canopy.load_study_job:Loading job index 720
# INFO:canopy.load_study_job:Loading job index 721
# INFO:canopy.load_study_job:Loading job index 722
# INFO:canopy.load_study_job:Loading job index 723
# INFO:canopy.load_study_job:Loading job index 724
# INFO:canopy.load_study_job:Loading job index 725
# INFO:canopy.load_study_job:Loading job index 726
# INFO:canopy.load_study_job:Loading job index 727
# INFO:canopy.load_study_job:Loading job index 728
# INFO:canopy.load_study_job:Loading job index 729
# INFO:canopy.load_study_job:Loading job index 730
# ...
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-786.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-786.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-786.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-789.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-789.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-789.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-789.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-789.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-789.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-789.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-789.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-789.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-789.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-790.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-790.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-790.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-790.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-790.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-790.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-790.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-790.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-790.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-790.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-803.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-803.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-803.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-803.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-803.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-803.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-803.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-803.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-803.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-803.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-814.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-814.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-814.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-814.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-814.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-814.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-814.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-814.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-814.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-814.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-822.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-822.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-822.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-822.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-822.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-822.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-822.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-822.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-822.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-822.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-835.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-835.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-835.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-835.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-835.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-835.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-835.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-835.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-835.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-835.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-844.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-844.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-844.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-844.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-844.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-844.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-844.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-844.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-844.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-844.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-848.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-848.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-848.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-848.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-848.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-848.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-848.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-848.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-848.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-848.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-868.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-868.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-868.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-868.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-868.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-868.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-868.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-868.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-868.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-868.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-880.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-880.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-880.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-880.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-880.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-880.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-880.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-880.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-880.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-880.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-913.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-913.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-913.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-913.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-913.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-913.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-913.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-913.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-913.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-913.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-916.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-916.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-916.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-916.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-916.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-916.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-916.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-916.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-916.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-916.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-918.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-918.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-918.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-918.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-918.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-918.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-918.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-918.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-918.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-918.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-932.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-932.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-932.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-932.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-932.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-932.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-932.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-932.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-932.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-932.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-948.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-948.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-948.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-948.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-948.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-948.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-948.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-948.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-948.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-948.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-963.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-963.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-963.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-963.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-963.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-963.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-963.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-963.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-963.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-963.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-995.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-995.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-995.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-995.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-995.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-995.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-995.
# Warning: Scalar 'RaceEng_kRoll' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-995.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-995.
# Warning: Scalar 'tLapTotal' not found in job 6f11e70e7f7745069d9e80f4e1b4435b-995.

# %% [markdown]
# ## Check the disqualified jobs
#
# Run the cell below to get the disqualified jobs which will be needed to identify the fastest car from the qualified jobs in the next step.

# %%
disqualified_jobs_data = get_disqualified_jobs_data_in_study_with_id_due_to_scalar_limit_violations(
    scalar_data=scalar_data
)

print(disqualified_jobs_data)

#Get the number of disqualified jobs
disqualified_jobs_count = len(disqualified_jobs_data.keys())
print(f"Number of disqualified jobs: {disqualified_jobs_count}")
# Out:
# {'6f11e70e7f7745069d9e80f4e1b4435b-0': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 6.208225, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.011549, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.009122, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': -4.366567, 'min_limit': -1.5, 'max_limit': 0.0}, {'scalar': 'tLapTotal', 'scalar_value': 80.388272, 'min_limit': 0.0, 'max_limit': 77.2468}], '6f11e70e7f7745069d9e80f4e1b4435b-1': [{'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.011872, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.007278, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberFEOS', 'scalar_value': 0.101286, 'min_limit': -3.5, 'max_limit': 0.0}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': -6.217797, 'min_limit': -1.5, 'max_limit': 0.0}], '6f11e70e7f7745069d9e80f4e1b4435b-2': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 1.022591, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.006395, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberFEOS', 'scalar_value': -4.113361, 'min_limit': -3.5, 'max_limit': 0.0}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': -3.113174, 'min_limit': -1.5, 'max_limit': 0.0}, {'scalar': 'tLapTotal', 'scalar_value': 80.91214, 'min_limit': 0.0, 'max_limit': 77.2468}], '6f11e70e7f7745069d9e80f4e1b4435b-3': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 1.483205, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.011694, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.005724, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': -5.936208, 'min_limit': -1.5, 'max_limit': 0.0}], '6f11e70e7f7745069d9e80f4e1b4435b-6': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 1.442671, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.011997, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.002155, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': -4.447622, 'min_limit': -1.5, 'max_limit': 0.0}, {'scalar': 'tLapTotal', 'scalar_value': 78.195452, 'min_limit': 0.0, 'max_limit': 77.2468}], '6f11e70e7f7745069d9e80f4e1b4435b-7': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 7.841276, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.010407, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.01052, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': -4.425976, 'min_limit': -1.5, 'max_limit': 0.0}, {'scalar': 'tLapTotal', 'scalar_value': 81.590415, 'min_limit': 0.0, 'max_limit': 77.2468}], '6f11e70e7f7745069d9e80f4e1b4435b-8': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 7.614259, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.011449, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.00706, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberFEOS', 'scalar_value': -4.934622, 'min_limit': -3.5, 'max_limit': 0.0}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': -5.699067, 'min_limit': -1.5, 'max_limit': 0.0}, {'scalar': 'tLapTotal', 'scalar_value': 80.492434, 'min_limit': 0.0, 'max_limit': 77.2468}], '6f11e70e7f7745069d9e80f4e1b4435b-9': [{'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.006167, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberFEOS', 'scalar_value': -3.584732, 'min_limit': -3.5, 'max_limit': 0.0}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': -4.514439, 'min_limit ...
# Number of disqualified jobs: 930

# %% [markdown]
# ## Get the job with the minimum tLapTotal
#
# Run the cell below to idnetify the fastest car from the lot, if there is any. Oops, looks like there isn't any, so we will need to repeat the process with another monte carlo sweep with some adjusted ranges.
#
# ![alt text](images/RaceEngChallenge/image-8.png)

# %%
# Create a list of job_ids to exclude from the analysis from the keys of disqualified_jobs_data
excluded_job_ids = list(disqualified_jobs_data.keys())

results = await get_job_with_minimum_scalar_value(
    session=session,
    study_id=study_id,
    sim_type='DynamicLap',
    scalar_name='tLapTotal',
    excluded_job_ids=excluded_job_ids
)

print(results)
# Out:
# INFO:canopy.load_study_job:Loading job index 0
# INFO:canopy.load_study_job:Loading job index 1
# INFO:canopy.load_study_job:Loading job index 2
# INFO:canopy.load_study_job:Loading job index 3
# INFO:canopy.load_study_job:Loading job index 4
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 5
# INFO:canopy.load_study_job:Loading job index 6
# INFO:canopy.load_study_job:Loading job index 7
# INFO:canopy.load_study_job:Loading job index 8
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 9
# INFO:canopy.load_study_job:Loading job index 10
# INFO:canopy.load_study_job:Loading job index 11
# INFO:canopy.load_study_job:Loading job index 12
# INFO:canopy.load_study_job:Loading job index 13
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 14
# INFO:canopy.load_study_job:Loading job index 15
# INFO:canopy.load_study_job:Loading job index 16
# INFO:canopy.load_study_job:Loading job index 17
# INFO:canopy.load_study_job:Loading job index 18
# INFO:canopy.load_study_job:Loading job index 19
# INFO:canopy.load_study_job:Loading job index 20
# INFO:canopy.load_study_job:Loading job index 21
# INFO:canopy.load_study_job:Loading job index 22
# INFO:canopy.load_study_job:Loading job index 23
# INFO:canopy.load_study_job:Loading job index 24
# INFO:canopy.load_study_job:Loading job index 25
# INFO:canopy.load_study_job:Loading job index 26
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 27
# INFO:canopy.load_study_job:Loading job index 28
# INFO:canopy.load_study_job:Loading job index 29
# INFO:canopy.load_study_job:Loading job index 30
# INFO:canopy.load_study_job:Loading job index 31
# INFO:canopy.load_study_job:Loading job index 32
# INFO:canopy.load_study_job:Loading job index 33
# INFO:canopy.load_study_job:Loading job index 34
# INFO:canopy.load_study_job:Loading job index 35
# INFO:canopy.load_study_job:Loading job index 36
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 37
# INFO:canopy.load_study_job:Loading job index 38
# INFO:canopy.load_study_job:Loading job index 39
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 40
# INFO:canopy.load_study_job:Loading job index 41
# INFO:canopy.load_study_job:Loading job index 42
# INFO:canopy.load_study_job:Loading job index 43
# INFO:canopy.load_study_job:Loading job index 44
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 45
# INFO:canopy.load_study_job:Loading job index 46
# INFO:canopy.load_study_job:Loading job index 47
# INFO:canopy.load_study_job:Loading job index 48
# INFO:canopy.load_study_job:Loading job index 49
# INFO:canopy.load_study_job:Loading job index 50
# INFO:canopy.load_study_job:Loading job index 51
# INFO:canopy.load_study_job:Loading job index 52
# INFO:canopy.load_study_job:Loading job index 53
# INFO:canopy.load_study_job:Loading job index 54
# INFO:canopy.load_study_job:Loading job index 55
# INFO:canopy.load_study_job:Loading job index 56
# INFO:canopy.load_study_job:Loading job index 57
# INFO:canopy.load_study_job:Loading job index 58
# INFO:canopy.load_study_job:Loading job index 59
# INFO:canopy.load_study_job:Loading job index 60
# INFO:canopy.load_study_job:Loading job index 61
# INFO:canopy.load_study_job:Loading job index 62
# INFO:canopy.load_study_job:Loading job index 63
# INFO:canopy.load_study_job:Loading job index 64
# INFO:canopy.load_study_job:Loading job index 65
# INFO:canopy.load_study_job:Loading job index 66
# INFO:canopy.load_study_job:Loading job index 67
# INFO:canopy.load_study_job:Loading job index 68
# INFO:canopy.load_study_job:Loading job index 69
# INFO:canopy.load_study_job:Loading job index 70
# INFO:canopy.load_study_job:Loading job index 71
# INFO:canopy.load_study_job:Loading job index 72
# INFO:canopy.load_study_job:Loading job index 73
# INFO:canopy.load_study_job:Loading job index 74
# INFO:canopy.load_study_job:Loading job index 75
# INFO:canopy.load_study_job:Loading job index 76
# INFO:canopy.load_study_job:Loading job index 77
# INFO:canopy.load_study_job:Loading job index 78
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 79
# INFO:canopy.load_study_job:Loading job index 80
# INFO:canopy.load_study_job:Loading job index 81
# INFO:canopy.load_study_job:Loading job index 82
# INFO:canopy.load_study_job:Loading job index 83
# INFO:canopy.load_study_job:Loading job index 84
# INFO:canopy.load_study_job:Loading job index 85
# INFO:canopy.load_study_job:Loading job index 86
# INFO:canopy.load_study_job:Loading job index 87
# INFO:canopy.load_study_job:Loading job index 88
# INFO:canopy.load_study_job:Loading job index 89
# INFO:canopy.load_study_job:Loading job index 90
# INFO:canopy.load_study_job:Loading job index 91
# INFO:canopy.load_study_job:Loading job index 92
# INFO:canopy.load_study_job:Loading job index 93
# INFO:canopy.load_study_job:Loading job index 94
# INFO:canopy.load_study_job:Loading job index 95
# INFO:canopy.load_study_job:Loading job index 96
# INFO:canopy.load_study_job:Loading job index 97
# INFO:canopy.load_study_job:Loading job index 98
# INFO:canopy.load_study_job:Loading job index 99
# INFO:canopy.load_study_job:Loading job index 100
# INFO:canopy.load_study_job:Loading job index 101
# INFO:canopy.load_study_job:Loading job index 102
# INFO:canopy.load_study_job:Loading job index 103
# INFO:canopy.load_study_job:Loading job index 104
# INFO:canopy.load_study_job:Loading job index 105
# INFO:canopy.load_study_job:Loading job index 106
# INFO:canopy.load_study_job:Loading job index 107
# INFO:canopy.load_study_job:Loading job index 108
# INFO:canopy.load_study_job:Loading job index 109
# INFO:canopy.load_study_job:Loading job index 110
# INFO:canopy.load_study_job:Loading job index 111
# INFO:canopy.load_study_job:Loading job index 112
# INFO:canopy.load_study_job:Loading job index 113
# INFO:canopy.load_study_job:Loading job index 114
# INFO:canopy.load_study_job:Loading job index 115
# INFO:canopy.load_study_job:Loading job index 116
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 117
# INFO:canopy.load_study_job:Loading job index 118
# INFO:canopy.load_study_job:Loading job index 119
# INFO:canopy.load_study_job:Loading job index 120
# INFO:canopy.load_study_job:Loading job index 121
# INFO:canopy.load_study_job:Loading job index 122
# INFO:canopy.load_study_job:Loading job index 123
# INFO:canopy.load_study_job:Loading job index 124
# INFO:canopy.load_study_job:Loading job index 125
# INFO:canopy.load_study_job:Loading job index 126
# INFO:canopy.load_study_job:Loading job index 127
# INFO:canopy.load_study_job:Loading job index 128
# INFO:canopy.load_study_job:Loading job index 129
# INFO:canopy.load_study_job:Loading job index 130
# INFO:canopy.load_study_job:Loading job index 131
# INFO:canopy.load_study_job:Loading job index 132
# INFO:canopy.load_study_job:Loading job index 133
# INFO:canopy.load_study_job:Loading job index 134
# INFO:canopy.load_study_job:Loading job index 135
# INFO:canopy.load_study_job:Loading job index 136
# INFO:canopy.load_study_job:Loading job index 137
# INFO:canopy.load_study_job:Loading job index 138
# INFO:canopy.load_study_job:Loading job index 139
# INFO:canopy.load_study_job:Loading job index 140
# INFO:canopy.load_study_job:Loading job index 141
# INFO:canopy.load_study_job:Loading job index 142
# INFO:canopy.load_study_job:Loading job index 143
# INFO:canopy.load_study_job:Loading job index 144
# INFO:canopy.load_study_job:Loading job index 145
# INFO:canopy.load_study_job:Loading job index 146
# INFO:canopy.load_study_job:Loading job index 147
# INFO:canopy.load_study_job:Loading job index 148
# INFO:canopy.load_study_job:Loading job index 149
# INFO:canopy.load_study_job:Loading job index 150
# INFO:canopy.load_study_job:Loading job index 151
# INFO:canopy.load_study_job:Loading job index 152
# INFO:canopy.load_study_job:Loading job index 153
# INFO:canopy.load_study_job:Loading job index 154
# INFO:canopy.load_study_job:Loading job index 155
# INFO:canopy.load_study_job:Loading job index 156
# INFO:canopy.load_study_job:Loading job index 157
# INFO:canopy.load_study_job:Loading job index 158
# INFO:canopy.load_study_job:Loading job index 159
# INFO:canopy.load_study_job:Loading job index 160
# INFO:canopy.load_study_job:Loading job index 161
# INFO:canopy.load_study_job:Loading job index 162
# INFO:canopy.load_study_job:Loading job index 163
# INFO:canopy.load_study_job:Loading job index 164
# INFO:canopy.load_study_job:Loading job index 165
# INFO:canopy.load_study_job:Loading job index 166
# INFO:canopy.load_study_job:Loading job index 167
# INFO:canopy.load_study_job:Loading job index 168
# INFO:canopy.load_study_job:Loading job index 169
# INFO:canopy.load_study_job:Loading job index 170
# INFO:canopy.load_study_job:Loading job index 171
# INFO:canopy.load_study_job:Loading job index 172
# INFO:canopy.load_study_job:Loading job index 173
# INFO:canopy.load_study_job:Loading job index 174
# INFO:canopy.load_study_job:Loading job index 175
# INFO:canopy.load_study_job:Loading job index 176
# INFO:canopy.load_study_job:Loading job index 177
# INFO:canopy.load_study_job:Loading job index 178
# INFO:canopy.load_study_job:Loading job index 179
# INFO:canopy.load_study_job:Loading job index 180
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 181
# INFO:canopy.load_study_job:Loading job index 182
# INFO:canopy.load_study_job:Loading job index 183
# INFO:canopy.load_study_job:Loading job index 184
# INFO:canopy.load_study_job:Loading job index 185
# INFO:canopy.load_study_job:Loading job index 186
# INFO:canopy.load_study_job:Loading job index 187
# INFO:canopy.load_study_job:Loading job index 188
# INFO:canopy.load_study_job:Loading job index 189
# INFO:canopy.load_study_job:Loading job index 190
# INFO:canopy.load_study_job:Loading job index 191
# INFO:canopy.load_study_job:Loading job index 192
# INFO:canopy.load_study_job:Loading job index 193
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 194
# INFO:canopy.load_study_job:Loading job index 195
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 196
# INFO:canopy.load_study_job:Loading job index 197
# INFO:canopy.load_study_job:Loading job index 198
# INFO:canopy.load_study_job:Loading job index 199
# INFO:canopy.load_study_job:Loading job index 200
# INFO:canopy.load_study_job:Loading job index 201
# INFO:canopy.load_study_job:Loading job index 202
# INFO:canopy.load_study_job:Loading job index 203
# INFO:canopy.load_study_job:Loading job index 204
# INFO:canopy.load_study_job:Loading job index 205
# INFO:canopy.load_study_job:Loading job index 206
# INFO:canopy.load_study_job:Loading job index 207
# INFO:canopy.load_study_job:Loading job index 208
# INFO:canopy.load_study_job:Loading job index 209
# INFO:canopy.load_study_job:Loading job index 210
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 211
# INFO:canopy.load_study_job:Loading job index 212
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 213
# INFO:canopy.load_study_job:Loading job index 214
# INFO:canopy.load_study_job:Loading job index 215
# INFO:canopy.load_study_job:Loading job index 216
# INFO:canopy.load_study_job:Loading job index 217
# INFO:canopy.load_study_job:Loading job index 218
# INFO:canopy.load_study_job:Loading job index 219
# INFO:canopy.load_study_job:Loading job index 220
# INFO:canopy.load_study_job:Loading job index 221
# INFO:canopy.load_study_job:Loading job index 222
# INFO:canopy.load_study_job:Loading job index 223
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 224
# INFO:canopy.load_study_job:Loading job index 225
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 226
# INFO:canopy.load_study_job:Loading job index 227
# INFO:canopy.load_study_job:Loading job index 228
# INFO:canopy.load_study_job:Loading job index 229
# INFO:canopy.load_study_job:Loading job index 230
# INFO:canopy.load_study_job:Loading job index 231
# INFO:canopy.load_study_job:Loading job index 232
# INFO:canopy.load_study_job:Loading job index 233
# INFO:canopy.load_study_job:Loading job index 234
# INFO:canopy.load_study_job:Loading job index 235
# INFO:canopy.load_study_job:Loading job index 236
# INFO:canopy.load_study_job:Loading job index 237
# INFO:canopy.load_study_job:Loading job index 238
# INFO:canopy.load_study_job:Loading job index 239
# INFO:canopy.load_study_job:Loading job index 240
# INFO:canopy.load_study_job:Loading job index 241
# INFO:canopy.load_study_job:Loading job index 242
# INFO:canopy.load_study_job:Loading job index 243
# INFO:canopy.load_study_job:Loading job index 244
# INFO:canopy.load_study_job:Loading job index 245
# INFO:canopy.load_study_job:Loading job index 246
# INFO:canopy.load_study_job:Loading job index 247
# INFO:canopy.load_study_job:Loading job index 248
# INFO:canopy.load_study_job:Loading job index 249
# INFO:canopy.load_study_job:Loading job index 250
# INFO:canopy.load_study_job:Loading job index 251
# INFO:canopy.load_study_job:Loading job index 252
# INFO:canopy.load_study_job:Loading job index 253
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 254
# INFO:canopy.load_study_job:Loading job index 255
# INFO:canopy.load_study_job:Loading job index 256
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 257
# INFO:canopy.load_study_job:Loading job index 258
# INFO:canopy.load_study_job:Loading job index 259
# INFO:canopy.load_study_job:Loading job index 260
# INFO:canopy.load_study_job:Loading job index 261
# INFO:canopy.load_study_job:Loading job index 262
# INFO:canopy.load_study_job:Loading job index 263
# INFO:canopy.load_study_job:Loading job index 264
# INFO:canopy.load_study_job:Loading job index 265
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 266
# INFO:canopy.load_study_job:Loading job index 267
# INFO:canopy.load_study_job:Loading job index 268
# INFO:canopy.load_study_job:Loading job index 269
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 270
# INFO:canopy.load_study_job:Loading job index 271
# INFO:canopy.load_study_job:Loading job index 272
# INFO:canopy.load_study_job:Loading job index 273
# INFO:canopy.load_study_job:Loading job index 274
# INFO:canopy.load_study_job:Loading job index 275
# INFO:canopy.load_study_job:Loading job index 276
# INFO:canopy.load_study_job:Loading job index 277
# INFO:canopy.load_study_job:Loading job index 278
# INFO:canopy.load_study_job:Loading job index 279
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 280
# INFO:canopy.load_study_job:Loading job index 281
# INFO:canopy.load_study_job:Loading job index 282
# INFO:canopy.load_study_job:Loading job index 283
# INFO:canopy.load_study_job:Loading job index 284
# INFO:canopy.load_study_job:Loading job index 285
# INFO:canopy.load_study_job:Loading job index 286
# INFO:canopy.load_study_job:Loading job index 287
# INFO:canopy.load_study_job:Loading job index 288
# INFO:canopy.load_study_job:Loading job index 289
# INFO:canopy.load_study_job:Loading job index 290
# INFO:canopy.load_study_job:Loading job index 291
# INFO:canopy.load_study_job:Loading job index 292
# INFO:canopy.load_study_job:Loading job index 293
# INFO:canopy.load_study_job:Loading job index 294
# INFO:canopy.load_study_job:Loading job index 295
# INFO:canopy.load_study_job:Loading job index 296
# INFO:canopy.load_study_job:Loading job index 297
# INFO:canopy.load_study_job:Loading job index 298
# INFO:canopy.load_study_job:Loading job index 299
# INFO:canopy.load_study_job:Loading job index 300
# INFO:canopy.load_study_job:Loading job index 301
# INFO:canopy.load_study_job:Loading job index 302
# INFO:canopy.load_study_job:Loading job index 303
# INFO:canopy.load_study_job:Loading job index 304
# INFO:canopy.load_study_job:Loading job index 305
# INFO:canopy.load_study_job:Loading job index 306
# INFO:canopy.load_study_job:Loading job index 307
# INFO:canopy.load_study_job:Loading job index 308
# INFO:canopy.load_study_job:Loading job index 309
# INFO:canopy.load_study_job:Loading job index 310
# INFO:canopy.load_study_job:Loading job index 311
# INFO:canopy.load_study_job:Loading job index 312
# INFO:canopy.load_study_job:Loading job index 313
# INFO:canopy.load_study_job:Loading job index 314
# INFO:canopy.load_study_job:Loading job index 315
# INFO:canopy.load_study_job:Loading job index 316
# INFO:canopy.load_study_job:Loading job index 317
# INFO:canopy.load_study_job:Loading job index 318
# INFO:canopy.load_study_job:Loading job index 319
# INFO:canopy.load_study_job:Loading job index 320
# INFO:canopy.load_study_job:Loading job index 321
# INFO:canopy.load_study_job:Loading job index 322
# INFO:canopy.load_study_job:Loading job index 323
# INFO:canopy.load_study_job:Loading job index 324
# INFO:canopy.load_study_job:Loading job index 325
# INFO:canopy.load_study_job:Loading job index 326
# INFO:canopy.load_study_job:Loading job index 327
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 328
# INFO:canopy.load_study_job:Loading job index 329
# INFO:canopy.load_study_job:Loading job index 330
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 331
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 332
# INFO:canopy.load_study_job:Loading job index 333
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 334
# INFO:canopy.load_study_job:Loading job index 335
# INFO:canopy.load_study_job:Loading job index 336
# INFO:canopy.load_study_job:Loading job index 337
# INFO:canopy.load_study_job:Loading job index 338
# INFO:canopy.load_study_job:Loading job index 339
# INFO:canopy.load_study_job:Loading job index 340
# INFO:canopy.load_study_job:Loading job index 341
# INFO:canopy.load_study_job:Loading job index 342
# INFO:canopy.load_study_job:Loading job index 343
# INFO:canopy.load_study_job:Loading job index 344
# INFO:canopy.load_study_job:Loading job index 345
# INFO:canopy.load_study_job:Loading job index 346
# INFO:canopy.load_study_job:Loading job index 347
# INFO:canopy.load_study_job:Loading job index 348
# INFO:canopy.load_study_job:Loading job index 349
# INFO:canopy.load_study_job:Loading job index 350
# INFO:canopy.load_study_job:Loading job index 351
# INFO:canopy.load_study_job:Loading job index 352
# INFO:canopy.load_study_job:Loading job index 353
# INFO:canopy.load_study_job:Loading job index 354
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 355
# INFO:canopy.load_study_job:Loading job index 356
# INFO:canopy.load_study_job:Loading job index 357
# INFO:canopy.load_study_job:Loading job index 358
# INFO:canopy.load_study_job:Loading job index 359
# INFO:canopy.load_study_job:Loading job index 360
# INFO:canopy.load_study_job:Loading job index 361
# INFO:canopy.load_study_job:Loading job index 362
# INFO:canopy.load_study_job:Loading job index 363
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 364
# INFO:canopy.load_study_job:Loading job index 365
# INFO:canopy.load_study_job:Loading job index 366
# INFO:canopy.load_study_job:Loading job index 367
# INFO:canopy.load_study_job:Loading job index 368
# INFO:canopy.load_study_job:Loading job index 369
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 370
# INFO:canopy.load_study_job:Loading job index 371
# INFO:canopy.load_study_job:Loading job index 372
# INFO:canopy.load_study_job:Loading job index 373
# INFO:canopy.load_study_job:Loading job index 374
# INFO:canopy.load_study_job:Loading job index 375
# INFO:canopy.load_study_job:Loading job index 376
# INFO:canopy.load_study_job:Loading job index 377
# INFO:canopy.load_study_job:Loading job index 378
# INFO:canopy.load_study_job:Loading job index 379
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 380
# INFO:canopy.load_study_job:Loading job index 381
# INFO:canopy.load_study_job:Loading job index 382
# INFO:canopy.load_study_job:Loading job index 383
# INFO:canopy.load_study_job:Loading job index 384
# INFO:canopy.load_study_job:Loading job index 385
# INFO:canopy.load_study_job:Loading job index 386
# INFO:canopy.load_study_job:Loading job index 387
# INFO:canopy.load_study_job:Loading job index 388
# INFO:canopy.load_study_job:Loading job index 389
# INFO:canopy.load_study_job:Loading job index 390
# INFO:canopy.load_study_job:Loading job index 391
# INFO:canopy.load_study_job:Loading job index 392
# INFO:canopy.load_study_job:Loading job index 393
# INFO:canopy.load_study_job:Loading job index 394
# INFO:canopy.load_study_job:Loading job index 395
# INFO:canopy.load_study_job:Loading job index 396
# INFO:canopy.load_study_job:Loading job index 397
# INFO:canopy.load_study_job:Loading job index 398
# INFO:canopy.load_study_job:Loading job index 399
# INFO:canopy.load_study_job:Loading job index 400
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 401
# INFO:canopy.load_study_job:Loading job index 402
# INFO:canopy.load_study_job:Loading job index 403
# INFO:canopy.load_study_job:Loading job index 404
# INFO:canopy.load_study_job:Loading job index 405
# INFO:canopy.load_study_job:Loading job index 406
# INFO:canopy.load_study_job:Loading job index 407
# INFO:canopy.load_study_job:Loading job index 408
# INFO:canopy.load_study_job:Loading job index 409
# INFO:canopy.load_study_job:Loading job index 410
# INFO:canopy.load_study_job:Loading job index 411
# INFO:canopy.load_study_job:Loading job index 412
# INFO:canopy.load_study_job:Loading job index 413
# INFO:canopy.load_study_job:Loading job index 414
# INFO:canopy.load_study_job:Loading job index 415
# INFO:canopy.load_study_job:Loading job index 416
# INFO:canopy.load_study_job:Loading job index 417
# INFO:canopy.load_study_job:Loading job index 418
# INFO:canopy.load_study_job:Loading job index 419
# INFO:canopy.load_study_job:Loading job index 420
# INFO:canopy.load_study_job:Loading job index 421
# INFO:canopy.load_study_job:Loading job index 422
# INFO:canopy.load_study_job:Loading job index 423
# INFO:canopy.load_study_job:Loading job index 424
# INFO:canopy.load_study_job:Loading job index 425
# INFO:canopy.load_study_job:Loading job index 426
# INFO:canopy.load_study_job:Loading job index 427
# INFO:canopy.load_study_job:Loading job index 428
# INFO:canopy.load_study_job:Loading job index 429
# INFO:canopy.load_study_job:Loading job index 430
# INFO:canopy.load_study_job:Loading job index 431
# INFO:canopy.load_study_job:Loading job index 432
# INFO:canopy.load_study_job:Loading job index 433
# INFO:canopy.load_study_job:Loading job index 434
# INFO:canopy.load_study_job:Loading job index 435
# INFO:canopy.load_study_job:Loading job index 436
# INFO:canopy.load_study_job:Loading job index 437
# INFO:canopy.load_study_job:Loading job index 438
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 439
# INFO:canopy.load_study_job:Loading job index 440
# INFO:canopy.load_study_job:Loading job index 441
# INFO:canopy.load_study_job:Loading job index 442
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 443
# INFO:canopy.load_study_job:Loading job index 444
# INFO:canopy.load_study_job:Loading job index 445
# INFO:canopy.load_study_job:Loading job index 446
# INFO:canopy.load_study_job:Loading job index 447
# INFO:canopy.load_study_job:Loading job index 448
# INFO:canopy.load_study_job:Loading job index 449
# INFO:canopy.load_study_job:Loading job index 450
# INFO:canopy.load_study_job:Loading job index 451
# INFO:canopy.load_study_job:Loading job index 452
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 453
# INFO:canopy.load_study_job:Loading job index 454
# INFO:canopy.load_study_job:Loading job index 455
# INFO:canopy.load_study_job:Loading job index 456
# INFO:canopy.load_study_job:Loading job index 457
# INFO:canopy.load_study_job:Loading job index 458
# INFO:canopy.load_study_job:Loading job index 459
# INFO:canopy.load_study_job:Loading job index 460
# INFO:canopy.load_study_job:Loading job index 461
# INFO:canopy.load_study_job:Loading job index 462
# INFO:canopy.load_study_job:Loading job index 463
# INFO:canopy.load_study_job:Loading job index 464
# INFO:canopy.load_study_job:Loading job index 465
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 466
# INFO:canopy.load_study_job:Loading job index 467
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 468
# INFO:canopy.load_study_job:Loading job index 469
# INFO:canopy.load_study_job:Loading job index 470
# INFO:canopy.load_study_job:Loading job index 471
# INFO:canopy.load_study_job:Loading job index 472
# INFO:canopy.load_study_job:Loading job index 473
# INFO:canopy.load_study_job:Loading job index 474
# INFO:canopy.load_study_job:Loading job index 475
# INFO:canopy.load_study_job:Loading job index 476
# INFO:canopy.load_study_job:Loading job index 477
# INFO:canopy.load_study_job:Loading job index 478
# INFO:canopy.load_study_job:Loading job index 479
# INFO:canopy.load_study_job:Loading job index 480
# INFO:canopy.load_study_job:Loading job index 481
# INFO:canopy.load_study_job:Loading job index 482
# INFO:canopy.load_study_job:Loading job index 483
# INFO:canopy.load_study_job:Loading job index 484
# INFO:canopy.load_study_job:Loading job index 485
# INFO:canopy.load_study_job:Loading job index 486
# INFO:canopy.load_study_job:Loading job index 487
# INFO:canopy.load_study_job:Loading job index 488
# INFO:canopy.load_study_job:Loading job index 489
# INFO:canopy.load_study_job:Loading job index 490
# INFO:canopy.load_study_job:Loading job index 491
# INFO:canopy.load_study_job:Loading job index 492
# INFO:canopy.load_study_job:Loading job index 493
# INFO:canopy.load_study_job:Loading job index 494
# INFO:canopy.load_study_job:Loading job index 495
# INFO:canopy.load_study_job:Loading job index 496
# INFO:canopy.load_study_job:Loading job index 497
# INFO:canopy.load_study_job:Loading job index 498
# INFO:canopy.load_study_job:Loading job index 499
# INFO:canopy.load_study_job:Loading job index 500
# INFO:canopy.load_study_job:Loading job index 501
# INFO:canopy.load_study_job:Loading job index 502
# INFO:canopy.load_study_job:Loading job index 503
# INFO:canopy.load_study_job:Loading job index 504
# INFO:canopy.load_study_job:Loading job index 505
# INFO:canopy.load_study_job:Loading job index 506
# INFO:canopy.load_study_job:Loading job index 507
# INFO:canopy.load_study_job:Loading job index 508
# INFO:canopy.load_study_job:Loading job index 509
# INFO:canopy.load_study_job:Loading job index 510
# INFO:canopy.load_study_job:Loading job index 511
# INFO:canopy.load_study_job:Loading job index 512
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 513
# INFO:canopy.load_study_job:Loading job index 514
# INFO:canopy.load_study_job:Loading job index 515
# INFO:canopy.load_study_job:Loading job index 516
# INFO:canopy.load_study_job:Loading job index 517
# INFO:canopy.load_study_job:Loading job index 518
# INFO:canopy.load_study_job:Loading job index 519
# INFO:canopy.load_study_job:Loading job index 520
# INFO:canopy.load_study_job:Loading job index 521
# INFO:canopy.load_study_job:Loading job index 522
# INFO:canopy.load_study_job:Loading job index 523
# INFO:canopy.load_study_job:Loading job index 524
# INFO:canopy.load_study_job:Loading job index 525
# INFO:canopy.load_study_job:Loading job index 526
# INFO:canopy.load_study_job:Loading job index 527
# INFO:canopy.load_study_job:Loading job index 528
# INFO:canopy.load_study_job:Loading job index 529
# INFO:canopy.load_study_job:Loading job index 530
# INFO:canopy.load_study_job:Loading job index 531
# INFO:canopy.load_study_job:Loading job index 532
# INFO:canopy.load_study_job:Loading job index 533
# INFO:canopy.load_study_job:Loading job index 534
# INFO:canopy.load_study_job:Loading job index 535
# INFO:canopy.load_study_job:Loading job index 536
# INFO:canopy.load_study_job:Loading job index 537
# INFO:canopy.load_study_job:Loading job index 538
# INFO:canopy.load_study_job:Loading job index 539
# INFO:canopy.load_study_job:Loading job index 540
# INFO:canopy.load_study_job:Loading job index 541
# INFO:canopy.load_study_job:Loading job index 542
# INFO:canopy.load_study_job:Loading job index 543
# INFO:canopy.load_study_job:Loading job index 544
# INFO:canopy.load_study_job:Loading job index 545
# INFO:canopy.load_study_job:Loading job index 546
# INFO:canopy.load_study_job:Loading job index 547
# INFO:canopy.load_study_job:Loading job index 548
# INFO:canopy.load_study_job:Loading job index 549
# INFO:canopy.load_study_job:Loading job index 550
# INFO:canopy.load_study_job:Loading job index 551
# INFO:canopy.load_study_job:Loading job index 552
# INFO:canopy.load_study_job:Loading job index 553
# INFO:canopy.load_study_job:Loading job index 554
# INFO:canopy.load_study_job:Loading job index 555
# INFO:canopy.load_study_job:Loading job index 556
# INFO:canopy.load_study_job:Loading job index 557
# INFO:canopy.load_study_job:Loading job index 558
# INFO:canopy.load_study_job:Loading job index 559
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 560
# INFO:canopy.load_study_job:Loading job index 561
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 562
# INFO:canopy.load_study_job:Loading job index 563
# INFO:canopy.load_study_job:Loading job index 564
# INFO:canopy.load_study_job:Loading job index 565
# INFO:canopy.load_study_job:Loading job index 566
# INFO:canopy.load_study_job:Loading job index 567
# INFO:canopy.load_study_job:Loading job index 568
# INFO:canopy.load_study_job:Loading job index 569
# INFO:canopy.load_study_job:Loading job index 570
# INFO:canopy.load_study_job:Loading job index 571
# INFO:canopy.load_study_job:Loading job index 572
# INFO:canopy.load_study_job:Loading job index 573
# INFO:canopy.load_study_job:Loading job index 574
# INFO:canopy.load_study_job:Loading job index 575
# INFO:canopy.load_study_job:Loading job index 576
# INFO:canopy.load_study_job:Loading job index 577
# INFO:canopy.load_study_job:Loading job index 578
# INFO:canopy.load_study_job:Loading job index 579
# INFO:canopy.load_study_job:Loading job index 580
# INFO:canopy.load_study_job:Loading job index 581
# INFO:canopy.load_study_job:Loading job index 582
# INFO:canopy.load_study_job:Loading job index 583
# INFO:canopy.load_study_job:Loading job index 584
# INFO:canopy.load_study_job:Loading job index 585
# INFO:canopy.load_study_job:Loading job index 586
# INFO:canopy.load_study_job:Loading job index 587
# INFO:canopy.load_study_job:Loading job index 588
# INFO:canopy.load_study_job:Loading job index 589
# INFO:canopy.load_study_job:Loading job index 590
# INFO:canopy.load_study_job:Loading job index 591
# INFO:canopy.load_study_job:Loading job index 592
# INFO:canopy.load_study_job:Loading job index 593
# INFO:canopy.load_study_job:Loading job index 594
# INFO:canopy.load_study_job:Loading job index 595
# INFO:canopy.load_study_job:Loading job index 596
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 597
# INFO:canopy.load_study_job:Loading job index 598
# INFO:canopy.load_study_job:Loading job index 599
# INFO:canopy.load_study_job:Loading job index 600
# INFO:canopy.load_study_job:Loading job index 601
# INFO:canopy.load_study_job:Loading job index 602
# INFO:canopy.load_study_job:Loading job index 603
# INFO:canopy.load_study_job:Loading job index 604
# INFO:canopy.load_study_job:Loading job index 605
# INFO:canopy.load_study_job:Loading job index 606
# INFO:canopy.load_study_job:Loading job index 607
# INFO:canopy.load_study_job:Loading job index 608
# INFO:canopy.load_study_job:Loading job index 609
# INFO:canopy.load_study_job:Loading job index 610
# INFO:canopy.load_study_job:Loading job index 611
# INFO:canopy.load_study_job:Loading job index 612
# INFO:canopy.load_study_job:Loading job index 613
# INFO:canopy.load_study_job:Loading job index 614
# INFO:canopy.load_study_job:Loading job index 615
# INFO:canopy.load_study_job:Loading job index 616
# INFO:canopy.load_study_job:Loading job index 617
# INFO:canopy.load_study_job:Loading job index 618
# INFO:canopy.load_study_job:Loading job index 619
# INFO:canopy.load_study_job:Loading job index 620
# INFO:canopy.load_study_job:Loading job index 621
# INFO:canopy.load_study_job:Loading job index 622
# INFO:canopy.load_study_job:Loading job index 623
# INFO:canopy.load_study_job:Loading job index 624
# INFO:canopy.load_study_job:Loading job index 625
# INFO:canopy.load_study_job:Loading job index 626
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 627
# INFO:canopy.load_study_job:Loading job index 628
# INFO:canopy.load_study_job:Loading job index 629
# INFO:canopy.load_study_job:Loading job index 630
# INFO:canopy.load_study_job:Loading job index 631
# INFO:canopy.load_study_job:Loading job index 632
# INFO:canopy.load_study_job:Loading job index 633
# INFO:canopy.load_study_job:Loading job index 634
# INFO:canopy.load_study_job:Loading job index 635
# INFO:canopy.load_study_job:Loading job index 636
# INFO:canopy.load_study_job:Loading job index 637
# INFO:canopy.load_study_job:Loading job index 638
# INFO:canopy.load_study_job:Loading job index 639
# INFO:canopy.load_study_job:Loading job index 640
# INFO:canopy.load_study_job:Loading job index 641
# INFO:canopy.load_study_job:Loading job index 642
# INFO:canopy.load_study_job:Loading job index 643
# INFO:canopy.load_study_job:Loading job index 644
# INFO:canopy.load_study_job:Loading job index 645
# INFO:canopy.load_study_job:Loading job index 646
# INFO:canopy.load_study_job:Loading job index 647
# INFO:canopy.load_study_job:Loading job index 648
# INFO:canopy.load_study_job:Loading job index 649
# INFO:canopy.load_study_job:Loading job index 650
# INFO:canopy.load_study_job:Loading job index 651
# INFO:canopy.load_study_job:Loading job index 652
# INFO:canopy.load_study_job:Loading job index 653
# INFO:canopy.load_study_job:Loading job index 654
# INFO:canopy.load_study_job:Loading job index 655
# INFO:canopy.load_study_job:Loading job index 656
# INFO:canopy.load_study_job:Loading job index 657
# INFO:canopy.load_study_job:Loading job index 658
# INFO:canopy.load_study_job:Loading job index 659
# INFO:canopy.load_study_job:Loading job index 660
# INFO:canopy.load_study_job:Loading job index 661
# INFO:canopy.load_study_job:Loading job index 662
# INFO:canopy.load_study_job:Loading job index 663
# INFO:canopy.load_study_job:Loading job index 664
# INFO:canopy.load_study_job:Loading job index 665
# INFO:canopy.load_study_job:Loading job index 666
# INFO:canopy.load_study_job:Loading job index 667
# INFO:canopy.load_study_job:Loading job index 668
# INFO:canopy.load_study_job:Loading job index 669
# INFO:canopy.load_study_job:Loading job index 670
# INFO:canopy.load_study_job:Loading job index 671
# INFO:canopy.load_study_job:Loading job index 672
# INFO:canopy.load_study_job:Loading job index 673
# INFO:canopy.load_study_job:Loading job index 674
# INFO:canopy.load_study_job:Loading job index 675
# INFO:canopy.load_study_job:Loading job index 676
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 677
# INFO:canopy.load_study_job:Loading job index 678
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 679
# INFO:canopy.load_study_job:Loading job index 680
# INFO:canopy.load_study_job:Loading job index 681
# INFO:canopy.load_study_job:Loading job index 682
# INFO:canopy.load_study_job:Loading job index 683
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 684
# INFO:canopy.load_study_job:Loading job index 685
# INFO:canopy.load_study_job:Loading job index 686
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 687
# INFO:canopy.load_study_job:Loading job index 688
# INFO:canopy.load_study_job:Loading job index 689
# INFO:canopy.load_study_job:Loading job index 690
# INFO:canopy.load_study_job:Loading job index 691
# INFO:canopy.load_study_job:Loading job index 692
# INFO:canopy.load_study_job:Loading job index 693
# INFO:canopy.load_study_job:Loading job index 694
# INFO:canopy.load_study_job:Loading job index 695
# INFO:canopy.load_study_job:Loading job index 696
# INFO:canopy.load_study_job:Loading job index 697
# INFO:canopy.load_study_job:Loading job index 698
# INFO:canopy.load_study_job:Loading job index 699
# INFO:canopy.load_study_job:Loading job index 700
# INFO:canopy.load_study_job:Loading job index 701
# INFO:canopy.load_study_job:Loading job index 702
# INFO:canopy.load_study_job:Loading job index 703
# INFO:canopy.load_study_job:Loading job index 704
# INFO:canopy.load_study_job:Loading job index 705
# INFO:canopy.load_study_job:Loading job index 706
# INFO:canopy.load_study_job:Loading job index 707
# INFO:canopy.load_study_job:Loading job index 708
# INFO:canopy.load_study_job:Loading job index 709
# INFO:canopy.load_study_job:Loading job index 710
# INFO:canopy.load_study_job:Loading job index 711
# INFO:canopy.load_study_job:Loading job index 712
# INFO:canopy.load_study_job:Loading job index 713
# INFO:canopy.load_study_job:Loading job index 714
# INFO:canopy.load_study_job:Loading job index 715
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 716
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 717
# INFO:canopy.load_study_job:Loading job index 718
# INFO:canopy.load_study_job:Loading job index 719
# INFO:canopy.load_study_job:Loading job index 720
# INFO:canopy.load_study_job:Loading job index 721
# INFO:canopy.load_study_job:Loading job index 722
# INFO:canopy.load_study_job:Loading job index 723
# INFO:canopy.load_study_job:Loading job index 724
# INFO:canopy.load_study_job:Loading job index 725
# INFO:canopy.load_study_job:Loading job index 726
# INFO:canopy.load_study_job:Loading job index 727
# INFO:canopy.load_study_job:Loading job index 728
# INFO:canopy.load_study_job:Loading job index 729
# INFO:canopy.load_study_job:Loading job index 730
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# ...
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 838
# INFO:canopy.load_study_job:Loading job index 839
# INFO:canopy.load_study_job:Loading job index 840
# INFO:canopy.load_study_job:Loading job index 841
# INFO:canopy.load_study_job:Loading job index 842
# INFO:canopy.load_study_job:Loading job index 843
# INFO:canopy.load_study_job:Loading job index 844
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 845
# INFO:canopy.load_study_job:Loading job index 846
# INFO:canopy.load_study_job:Loading job index 847
# INFO:canopy.load_study_job:Loading job index 848
# INFO:canopy.load_study_job:Loading job index 849
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 850
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 851
# INFO:canopy.load_study_job:Loading job index 852
# INFO:canopy.load_study_job:Loading job index 853
# INFO:canopy.load_study_job:Loading job index 854
# INFO:canopy.load_study_job:Loading job index 855
# INFO:canopy.load_study_job:Loading job index 856
# INFO:canopy.load_study_job:Loading job index 857
# INFO:canopy.load_study_job:Loading job index 858
# INFO:canopy.load_study_job:Loading job index 859
# INFO:canopy.load_study_job:Loading job index 860
# INFO:canopy.load_study_job:Loading job index 861
# INFO:canopy.load_study_job:Loading job index 862
# INFO:canopy.load_study_job:Loading job index 863
# INFO:canopy.load_study_job:Loading job index 864
# INFO:canopy.load_study_job:Loading job index 865
# INFO:canopy.load_study_job:Loading job index 866
# INFO:canopy.load_study_job:Loading job index 867
# INFO:canopy.load_study_job:Loading job index 868
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 869
# INFO:canopy.load_study_job:Loading job index 870
# INFO:canopy.load_study_job:Loading job index 871
# INFO:canopy.load_study_job:Loading job index 872
# INFO:canopy.load_study_job:Loading job index 873
# INFO:canopy.load_study_job:Loading job index 874
# INFO:canopy.load_study_job:Loading job index 875
# INFO:canopy.load_study_job:Loading job index 876
# INFO:canopy.load_study_job:Loading job index 877
# INFO:canopy.load_study_job:Loading job index 878
# INFO:canopy.load_study_job:Loading job index 879
# INFO:canopy.load_study_job:Loading job index 880
# INFO:canopy.load_study_job:Loading job index 881
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 882
# INFO:canopy.load_study_job:Loading job index 883
# INFO:canopy.load_study_job:Loading job index 884
# INFO:canopy.load_study_job:Loading job index 885
# INFO:canopy.load_study_job:Loading job index 886
# INFO:canopy.load_study_job:Loading job index 887
# INFO:canopy.load_study_job:Loading job index 888
# INFO:canopy.load_study_job:Loading job index 889
# INFO:canopy.load_study_job:Loading job index 890
# INFO:canopy.load_study_job:Loading job index 891
# INFO:canopy.load_study_job:Loading job index 892
# INFO:canopy.load_study_job:Loading job index 893
# INFO:canopy.load_study_job:Loading job index 894
# INFO:canopy.load_study_job:Loading job index 895
# INFO:canopy.load_study_job:Loading job index 896
# INFO:canopy.load_study_job:Loading job index 897
# INFO:canopy.load_study_job:Loading job index 898
# INFO:canopy.load_study_job:Loading job index 899
# INFO:canopy.load_study_job:Loading job index 900
# INFO:canopy.load_study_job:Loading job index 901
# INFO:canopy.load_study_job:Loading job index 902
# INFO:canopy.load_study_job:Loading job index 903
# INFO:canopy.load_study_job:Loading job index 904
# INFO:canopy.load_study_job:Loading job index 905
# INFO:canopy.load_study_job:Loading job index 906
# INFO:canopy.load_study_job:Loading job index 907
# INFO:canopy.load_study_job:Loading job index 908
# INFO:canopy.load_study_job:Loading job index 909
# INFO:canopy.load_study_job:Loading job index 910
# INFO:canopy.load_study_job:Loading job index 911
# INFO:canopy.load_study_job:Loading job index 912
# INFO:canopy.load_study_job:Loading job index 913
# INFO:canopy.load_study_job:Loading job index 914
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 915
# INFO:canopy.load_study_job:Loading job index 916
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 917
# INFO:canopy.load_study_job:Loading job index 918
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 919
# INFO:canopy.load_study_job:Loading job index 920
# INFO:canopy.load_study_job:Loading job index 921
# INFO:canopy.load_study_job:Loading job index 922
# INFO:canopy.load_study_job:Loading job index 923
# INFO:canopy.load_study_job:Loading job index 924
# INFO:canopy.load_study_job:Loading job index 925
# INFO:canopy.load_study_job:Loading job index 926
# INFO:canopy.load_study_job:Loading job index 927
# INFO:canopy.load_study_job:Loading job index 928
# INFO:canopy.load_study_job:Loading job index 929
# INFO:canopy.load_study_job:Loading job index 930
# INFO:canopy.load_study_job:Loading job index 931
# INFO:canopy.load_study_job:Loading job index 932
# INFO:canopy.load_study_job:Loading job index 933
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 934
# INFO:canopy.load_study_job:Loading job index 935
# INFO:canopy.load_study_job:Loading job index 936
# INFO:canopy.load_study_job:Loading job index 937
# INFO:canopy.load_study_job:Loading job index 938
# INFO:canopy.load_study_job:Loading job index 939
# INFO:canopy.load_study_job:Loading job index 940
# INFO:canopy.load_study_job:Loading job index 941
# INFO:canopy.load_study_job:Loading job index 942
# INFO:canopy.load_study_job:Loading job index 943
# INFO:canopy.load_study_job:Loading job index 944
# INFO:canopy.load_study_job:Loading job index 945
# INFO:canopy.load_study_job:Loading job index 946
# INFO:canopy.load_study_job:Loading job index 947
# INFO:canopy.load_study_job:Loading job index 948
# INFO:canopy.load_study_job:Loading job index 949
# INFO:canopy.load_study_job:Loading job index 950
# INFO:canopy.load_study_job:Loading job index 951
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 952
# INFO:canopy.load_study_job:Loading job index 953
# INFO:canopy.load_study_job:Loading job index 954
# INFO:canopy.load_study_job:Loading job index 955
# INFO:canopy.load_study_job:Loading job index 956
# INFO:canopy.load_study_job:Loading job index 957
# INFO:canopy.load_study_job:Loading job index 958
# INFO:canopy.load_study_job:Loading job index 959
# INFO:canopy.load_study_job:Loading job index 960
# INFO:canopy.load_study_job:Loading job index 961
# INFO:canopy.load_study_job:Loading job index 962
# INFO:canopy.load_study_job:Loading job index 963
# INFO:canopy.load_study_job:Loading job index 964
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 965
# INFO:canopy.load_study_job:Loading job index 966
# INFO:canopy.load_study_job:Loading job index 967
# INFO:canopy.load_study_job:Loading job index 968
# INFO:canopy.load_study_job:Loading job index 969
# INFO:canopy.load_study_job:Loading job index 970
# INFO:canopy.load_study_job:Loading job index 971
# INFO:canopy.load_study_job:Loading job index 972
# INFO:canopy.load_study_job:Loading job index 973
# INFO:canopy.load_study_job:Loading job index 974
# INFO:canopy.load_study_job:Loading job index 975
# INFO:canopy.load_study_job:Loading job index 976
# INFO:canopy.load_study_job:Loading job index 977
# INFO:canopy.load_study_job:Loading job index 978
# INFO:canopy.load_study_job:Loading job index 979
# INFO:canopy.load_study_job:Loading job index 980
# INFO:canopy.load_study_job:Loading job index 981
# INFO:canopy.load_study_job:Loading job index 982
# INFO:canopy.load_study_job:Loading job index 983
# INFO:canopy.load_study_job:Loading job index 984
# INFO:canopy.load_study_job:Loading job index 985
# INFO:canopy.load_study_job:Loading job index 986
# INFO:canopy.load_study_job:Loading job index 987
# INFO:canopy.load_study_job:Loading job index 988
# INFO:canopy.load_study_job:Loading job index 989
# INFO:canopy.load_study_job:Loading job index 990
# INFO:canopy.load_study_job:Loading job index 991
# INFO:canopy.load_study_job:Loading job index 992
# INFO:canopy.load_study_job:Loading job index 993
# INFO:canopy.load_study_job:Loading job index 994
# INFO:canopy.load_study_job:Loading job index 995
# INFO:canopy.load_study_job:Loading job index 996
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 997
# INFO:canopy.load_study_job:Loading job index 998
# INFO:canopy.load_study_job:Loading job index 999
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-4 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-5 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-13 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-24 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-36 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-37 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-38 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-44 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-78 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-116 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-180 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-191 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-192 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-194 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-195 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-209 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-212 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-222 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-225 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-249 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-254 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-264 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-267 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-278 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-326 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-329 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-331 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-333 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-354 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-363 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-369 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-375 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-379 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-398 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-438 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-442 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-452 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-464 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-466 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-512 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-557 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-560 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-595 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-625 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-674 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-678 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-682 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-686 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-714 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-730 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-745 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-756 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-786 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-789 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-790 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-803 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-814 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-822 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-835 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-844 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-848 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-868 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-880 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-913 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-916 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-918 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-932 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-948 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-963 for scalar tLapTotal...
# Checking job 6f11e70e7f7745069d9e80f4e1b4435b-995 for scalar tLapTotal...
# (None, inf)

# %% [markdown]
# ## No jobs meeting the requirements found, so run again.
#
# Now, the question of how to identify which numbers to use for the next iteration comes up.
#
# If you want to fully automate the process, this should be possible by writing up a fancy algorithm of your choosing and calling these functions iteratively until you hit a limit.
#
# Or, you can go quick and dirty by taking a look at the cross section plots and visually observing the trend of tLapTotal:DynamicLap with each swept parameter.
#
# ![alt text](images/RaceEngChallenge/image-9.png)

# %%
swept_parameter_data_1 = [
    { 
        'id': 'hRideFSetup',
        'path': 'car.chassis.hRideFSetup',
        'min': 0.02,
        'max': 0.03
    },
    {
        'id': 'hRideRSetup',
        'path': 'car.chassis.hRideRSetup',
        'min': 0.06,
        'max': 0.08
    },
    {
        'id': 'aFlapF',
        'path': 'car.aero.flapAngles.aFlapF',
        'min': 0.4,
        'max': 0.6
    },
    # {
    #     'id':'rWeightBalF',
    #     'path':'car.chassis.carRunningMass.rWeightBalF',
    #     'min': 0.45,
    #     'max': 0.45
    # },
    {
        'id':'aCamberSetupF',
        'path':'car.suspension.front.external.aCamberSetupAlignment.aCamberSetup',
        'min': -0.1,
        'max': 0.1
    },
    {
        'id':'aCamberSetupR',
        'path':'car.suspension.rear.external.aCamberSetupAlignment.aCamberSetup',
        'min': -0.1,
        'max': 0.1
    },
    # {
    #     'id': 'kAntiRollBarF',
    #     'path': 'car.suspension.front.internal.antiRollBar.kAntiRollBar',
    #     'min': 0.0,
    #     'max': 100000.0
    # },
    # {
    #     'id': 'kAntiRollBarR',
    #     'path': 'car.suspension.rear.internal.antiRollBar.kAntiRollBar',
    #     'min': 0.0,
    #     'max': 100000.0
    # },
    # {
    #     'id': 'kTorsionBarF',
    #     'path': 'car.suspension.front.internal.torsionBar.kTorsionBar',
    #     'min': 0.0,
    #     'max': 10000.0
    # },
    # {
    #     'id': 'kTorsionBarR',
    #     'path': 'car.suspension.rear.internal.triSpring.kSpring',
    #     'min': 0.0,
    #     'max': 10000.0
    # }
]

# %% [markdown]
# ## Run study with new exploration
#
# Let's call this exploration_mc_1

# %%
# List to hold the new config ids
config_ids = [
]

# Create a Monte Carlo exploration config
exploration_config_id = await create_monte_carlo_exploration_config_from_swept_parameter_data(
    session=session,
    name='exploration_mc_1',
    sim_version=sim_version,
    swept_parameter_data=swept_parameter_data_1,
    n_monte_carlo_points=1000
)

# print(exploration_config_id)

result = await run_worksheet_row_study_with_configs_having_ids(
    session=session,
    worksheet_id=worksheet_id,
    source_row_name='base',
    sim_version=sim_version,
    row_suffix='exploration_mc_1',
    config_ids=[exploration_config_id]
)

worksheet_row_name = result['worksheet_row_name']
study_id = result['study_id']
worksheet_id = result['worksheet_id']

# %% [markdown]
# # Check if study with id is completed

# %%
# Comment this out if you run the cell above
study_id = '48fda98fb8a44663b831df56272bb99f'

study = await canopy.load_study(
    session=session,
    study_id=study_id,
)

print(f"study_state: {study.document.data['studyState']}")
# Out:
# WARNING:canopy.request_with_retry:Retrying https://api.canopysimulations.com/studies/a4ed02d5506c4237a58d520e151f74be/48fda98fb8a44663b831df56272bb99f/metadata
# study_state: completed

# %% [markdown]
# ## Re-check the scalar limits

# %%
scalar_data = await get_scalar_data_from_jobs_in_study_with_id(
    session=session,
    study_id=study_id,
    sim_type='DynamicLap',
    scalar_limits=dynamic_lap_scalar_limits
)

# print(scalar_data)
# Out:
# WARNING:canopy.request_with_retry:Retrying https://api.canopysimulations.com/studies/a4ed02d5506c4237a58d520e151f74be/48fda98fb8a44663b831df56272bb99f
# INFO:canopy.load_study_job:Loading job index 0
# INFO:canopy.load_study_job:Loading job index 1
# INFO:canopy.load_study_job:Loading job index 2
# INFO:canopy.load_study_job:Loading job index 3
# INFO:canopy.load_study_job:Loading job index 4
# WARNING:canopy.request_with_retry:Retrying https://api.canopysimulations.com/studies/a4ed02d5506c4237a58d520e151f74be/48fda98fb8a44663b831df56272bb99f/jobs/1/metadata
# WARNING:canopy.request_with_retry:Retrying https://api.canopysimulations.com/studies/a4ed02d5506c4237a58d520e151f74be/48fda98fb8a44663b831df56272bb99f/jobs/4/metadata
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 5
# INFO:canopy.load_study_job:Loading job index 6
# INFO:canopy.load_study_job:Loading job index 7
# INFO:canopy.load_study_job:Loading job index 8
# INFO:canopy.load_study_job:Loading job index 9
# INFO:canopy.load_study_job:Loading job index 10
# INFO:canopy.load_study_job:Loading job index 11
# INFO:canopy.load_study_job:Loading job index 12
# INFO:canopy.load_study_job:Loading job index 13
# INFO:canopy.load_study_job:Loading job index 14
# INFO:canopy.load_study_job:Loading job index 15
# INFO:canopy.load_study_job:Loading job index 16
# INFO:canopy.load_study_job:Loading job index 17
# INFO:canopy.load_study_job:Loading job index 18
# INFO:canopy.load_study_job:Loading job index 19
# INFO:canopy.load_study_job:Loading job index 20
# INFO:canopy.load_study_job:Loading job index 21
# INFO:canopy.load_study_job:Loading job index 22
# INFO:canopy.load_study_job:Loading job index 23
# INFO:canopy.load_study_job:Loading job index 24
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 25
# INFO:canopy.load_study_job:Loading job index 26
# INFO:canopy.load_study_job:Loading job index 27
# INFO:canopy.load_study_job:Loading job index 28
# INFO:canopy.load_study_job:Loading job index 29
# INFO:canopy.load_study_job:Loading job index 30
# INFO:canopy.load_study_job:Loading job index 31
# INFO:canopy.load_study_job:Loading job index 32
# INFO:canopy.load_study_job:Loading job index 33
# INFO:canopy.load_study_job:Loading job index 34
# INFO:canopy.load_study_job:Loading job index 35
# INFO:canopy.load_study_job:Loading job index 36
# INFO:canopy.load_study_job:Loading job index 37
# INFO:canopy.load_study_job:Loading job index 38
# INFO:canopy.load_study_job:Loading job index 39
# INFO:canopy.load_study_job:Loading job index 40
# INFO:canopy.load_study_job:Loading job index 41
# INFO:canopy.load_study_job:Loading job index 42
# INFO:canopy.load_study_job:Loading job index 43
# INFO:canopy.load_study_job:Loading job index 44
# INFO:canopy.load_study_job:Loading job index 45
# INFO:canopy.load_study_job:Loading job index 46
# INFO:canopy.load_study_job:Loading job index 47
# INFO:canopy.load_study_job:Loading job index 48
# INFO:canopy.load_study_job:Loading job index 49
# INFO:canopy.load_study_job:Loading job index 50
# INFO:canopy.load_study_job:Loading job index 51
# INFO:canopy.load_study_job:Loading job index 52
# INFO:canopy.load_study_job:Loading job index 53
# INFO:canopy.load_study_job:Loading job index 54
# INFO:canopy.load_study_job:Loading job index 55
# INFO:canopy.load_study_job:Loading job index 56
# INFO:canopy.load_study_job:Loading job index 57
# INFO:canopy.load_study_job:Loading job index 58
# INFO:canopy.load_study_job:Loading job index 59
# INFO:canopy.load_study_job:Loading job index 60
# INFO:canopy.load_study_job:Loading job index 61
# INFO:canopy.load_study_job:Loading job index 62
# INFO:canopy.load_study_job:Loading job index 63
# INFO:canopy.load_study_job:Loading job index 64
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 65
# INFO:canopy.load_study_job:Loading job index 66
# INFO:canopy.load_study_job:Loading job index 67
# INFO:canopy.load_study_job:Loading job index 68
# INFO:canopy.load_study_job:Loading job index 69
# INFO:canopy.load_study_job:Loading job index 70
# INFO:canopy.load_study_job:Loading job index 71
# INFO:canopy.load_study_job:Loading job index 72
# INFO:canopy.load_study_job:Loading job index 73
# INFO:canopy.load_study_job:Loading job index 74
# INFO:canopy.load_study_job:Loading job index 75
# INFO:canopy.load_study_job:Loading job index 76
# INFO:canopy.load_study_job:Loading job index 77
# INFO:canopy.load_study_job:Loading job index 78
# INFO:canopy.load_study_job:Loading job index 79
# INFO:canopy.load_study_job:Loading job index 80
# INFO:canopy.load_study_job:Loading job index 81
# INFO:canopy.load_study_job:Loading job index 82
# INFO:canopy.load_study_job:Loading job index 83
# INFO:canopy.load_study_job:Loading job index 84
# INFO:canopy.load_study_job:Loading job index 85
# INFO:canopy.load_study_job:Loading job index 86
# INFO:canopy.load_study_job:Loading job index 87
# INFO:canopy.load_study_job:Loading job index 88
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 89
# INFO:canopy.load_study_job:Loading job index 90
# INFO:canopy.load_study_job:Loading job index 91
# INFO:canopy.load_study_job:Loading job index 92
# INFO:canopy.load_study_job:Loading job index 93
# INFO:canopy.load_study_job:Loading job index 94
# INFO:canopy.load_study_job:Loading job index 95
# INFO:canopy.load_study_job:Loading job index 96
# INFO:canopy.load_study_job:Loading job index 97
# INFO:canopy.load_study_job:Loading job index 98
# INFO:canopy.load_study_job:Loading job index 99
# INFO:canopy.load_study_job:Loading job index 100
# INFO:canopy.load_study_job:Loading job index 101
# INFO:canopy.load_study_job:Loading job index 102
# INFO:canopy.load_study_job:Loading job index 103
# INFO:canopy.load_study_job:Loading job index 104
# INFO:canopy.load_study_job:Loading job index 105
# INFO:canopy.load_study_job:Loading job index 106
# INFO:canopy.load_study_job:Loading job index 107
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 108
# INFO:canopy.load_study_job:Loading job index 109
# INFO:canopy.load_study_job:Loading job index 110
# INFO:canopy.load_study_job:Loading job index 111
# INFO:canopy.load_study_job:Loading job index 112
# INFO:canopy.load_study_job:Loading job index 113
# INFO:canopy.load_study_job:Loading job index 114
# INFO:canopy.load_study_job:Loading job index 115
# INFO:canopy.load_study_job:Loading job index 116
# INFO:canopy.load_study_job:Loading job index 117
# INFO:canopy.load_study_job:Loading job index 118
# INFO:canopy.load_study_job:Loading job index 119
# INFO:canopy.load_study_job:Loading job index 120
# INFO:canopy.load_study_job:Loading job index 121
# INFO:canopy.load_study_job:Loading job index 122
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 123
# INFO:canopy.load_study_job:Loading job index 124
# INFO:canopy.load_study_job:Loading job index 125
# INFO:canopy.load_study_job:Loading job index 126
# INFO:canopy.load_study_job:Loading job index 127
# INFO:canopy.load_study_job:Loading job index 128
# INFO:canopy.load_study_job:Loading job index 129
# INFO:canopy.load_study_job:Loading job index 130
# INFO:canopy.load_study_job:Loading job index 131
# INFO:canopy.load_study_job:Loading job index 132
# INFO:canopy.load_study_job:Loading job index 133
# INFO:canopy.load_study_job:Loading job index 134
# INFO:canopy.load_study_job:Loading job index 135
# INFO:canopy.load_study_job:Loading job index 136
# INFO:canopy.load_study_job:Loading job index 137
# INFO:canopy.load_study_job:Loading job index 138
# INFO:canopy.load_study_job:Loading job index 139
# INFO:canopy.load_study_job:Loading job index 140
# INFO:canopy.load_study_job:Loading job index 141
# INFO:canopy.load_study_job:Loading job index 142
# INFO:canopy.load_study_job:Loading job index 143
# INFO:canopy.load_study_job:Loading job index 144
# INFO:canopy.load_study_job:Loading job index 145
# INFO:canopy.load_study_job:Loading job index 146
# INFO:canopy.load_study_job:Loading job index 147
# INFO:canopy.load_study_job:Loading job index 148
# INFO:canopy.load_study_job:Loading job index 149
# INFO:canopy.load_study_job:Loading job index 150
# INFO:canopy.load_study_job:Loading job index 151
# INFO:canopy.load_study_job:Loading job index 152
# INFO:canopy.load_study_job:Loading job index 153
# INFO:canopy.load_study_job:Loading job index 154
# INFO:canopy.load_study_job:Loading job index 155
# INFO:canopy.load_study_job:Loading job index 156
# INFO:canopy.load_study_job:Loading job index 157
# INFO:canopy.load_study_job:Loading job index 158
# INFO:canopy.load_study_job:Loading job index 159
# INFO:canopy.load_study_job:Loading job index 160
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 161
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 162
# INFO:canopy.load_study_job:Loading job index 163
# INFO:canopy.load_study_job:Loading job index 164
# INFO:canopy.load_study_job:Loading job index 165
# INFO:canopy.load_study_job:Loading job index 166
# INFO:canopy.load_study_job:Loading job index 167
# INFO:canopy.load_study_job:Loading job index 168
# INFO:canopy.load_study_job:Loading job index 169
# INFO:canopy.load_study_job:Loading job index 170
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 171
# INFO:canopy.load_study_job:Loading job index 172
# INFO:canopy.load_study_job:Loading job index 173
# INFO:canopy.load_study_job:Loading job index 174
# INFO:canopy.load_study_job:Loading job index 175
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 176
# INFO:canopy.load_study_job:Loading job index 177
# INFO:canopy.load_study_job:Loading job index 178
# INFO:canopy.load_study_job:Loading job index 179
# INFO:canopy.load_study_job:Loading job index 180
# INFO:canopy.load_study_job:Loading job index 181
# INFO:canopy.load_study_job:Loading job index 182
# INFO:canopy.load_study_job:Loading job index 183
# INFO:canopy.load_study_job:Loading job index 184
# INFO:canopy.load_study_job:Loading job index 185
# INFO:canopy.load_study_job:Loading job index 186
# INFO:canopy.load_study_job:Loading job index 187
# INFO:canopy.load_study_job:Loading job index 188
# INFO:canopy.load_study_job:Loading job index 189
# INFO:canopy.load_study_job:Loading job index 190
# INFO:canopy.load_study_job:Loading job index 191
# INFO:canopy.load_study_job:Loading job index 192
# INFO:canopy.load_study_job:Loading job index 193
# INFO:canopy.load_study_job:Loading job index 194
# INFO:canopy.load_study_job:Loading job index 195
# INFO:canopy.load_study_job:Loading job index 196
# INFO:canopy.load_study_job:Loading job index 197
# INFO:canopy.load_study_job:Loading job index 198
# INFO:canopy.load_study_job:Loading job index 199
# INFO:canopy.load_study_job:Loading job index 200
# INFO:canopy.load_study_job:Loading job index 201
# INFO:canopy.load_study_job:Loading job index 202
# INFO:canopy.load_study_job:Loading job index 203
# INFO:canopy.load_study_job:Loading job index 204
# INFO:canopy.load_study_job:Loading job index 205
# INFO:canopy.load_study_job:Loading job index 206
# INFO:canopy.load_study_job:Loading job index 207
# INFO:canopy.load_study_job:Loading job index 208
# INFO:canopy.load_study_job:Loading job index 209
# INFO:canopy.load_study_job:Loading job index 210
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 211
# INFO:canopy.load_study_job:Loading job index 212
# INFO:canopy.load_study_job:Loading job index 213
# INFO:canopy.load_study_job:Loading job index 214
# INFO:canopy.load_study_job:Loading job index 215
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 216
# INFO:canopy.load_study_job:Loading job index 217
# INFO:canopy.load_study_job:Loading job index 218
# INFO:canopy.load_study_job:Loading job index 219
# INFO:canopy.load_study_job:Loading job index 220
# INFO:canopy.load_study_job:Loading job index 221
# INFO:canopy.load_study_job:Loading job index 222
# INFO:canopy.load_study_job:Loading job index 223
# INFO:canopy.load_study_job:Loading job index 224
# INFO:canopy.load_study_job:Loading job index 225
# INFO:canopy.load_study_job:Loading job index 226
# INFO:canopy.load_study_job:Loading job index 227
# INFO:canopy.load_study_job:Loading job index 228
# INFO:canopy.load_study_job:Loading job index 229
# INFO:canopy.load_study_job:Loading job index 230
# INFO:canopy.load_study_job:Loading job index 231
# INFO:canopy.load_study_job:Loading job index 232
# INFO:canopy.load_study_job:Loading job index 233
# INFO:canopy.load_study_job:Loading job index 234
# INFO:canopy.load_study_job:Loading job index 235
# INFO:canopy.load_study_job:Loading job index 236
# INFO:canopy.load_study_job:Loading job index 237
# INFO:canopy.load_study_job:Loading job index 238
# INFO:canopy.load_study_job:Loading job index 239
# INFO:canopy.load_study_job:Loading job index 240
# INFO:canopy.load_study_job:Loading job index 241
# INFO:canopy.load_study_job:Loading job index 242
# INFO:canopy.load_study_job:Loading job index 243
# INFO:canopy.load_study_job:Loading job index 244
# INFO:canopy.load_study_job:Loading job index 245
# INFO:canopy.load_study_job:Loading job index 246
# INFO:canopy.load_study_job:Loading job index 247
# INFO:canopy.load_study_job:Loading job index 248
# INFO:canopy.load_study_job:Loading job index 249
# INFO:canopy.load_study_job:Loading job index 250
# INFO:canopy.load_study_job:Loading job index 251
# INFO:canopy.load_study_job:Loading job index 252
# INFO:canopy.load_study_job:Loading job index 253
# INFO:canopy.load_study_job:Loading job index 254
# INFO:canopy.load_study_job:Loading job index 255
# INFO:canopy.load_study_job:Loading job index 256
# INFO:canopy.load_study_job:Loading job index 257
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 258
# INFO:canopy.load_study_job:Loading job index 259
# INFO:canopy.load_study_job:Loading job index 260
# INFO:canopy.load_study_job:Loading job index 261
# INFO:canopy.load_study_job:Loading job index 262
# INFO:canopy.load_study_job:Loading job index 263
# INFO:canopy.load_study_job:Loading job index 264
# INFO:canopy.load_study_job:Loading job index 265
# INFO:canopy.load_study_job:Loading job index 266
# INFO:canopy.load_study_job:Loading job index 267
# INFO:canopy.load_study_job:Loading job index 268
# INFO:canopy.load_study_job:Loading job index 269
# INFO:canopy.load_study_job:Loading job index 270
# INFO:canopy.load_study_job:Loading job index 271
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 272
# INFO:canopy.load_study_job:Loading job index 273
# INFO:canopy.load_study_job:Loading job index 274
# INFO:canopy.load_study_job:Loading job index 275
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 276
# INFO:canopy.load_study_job:Loading job index 277
# INFO:canopy.load_study_job:Loading job index 278
# INFO:canopy.load_study_job:Loading job index 279
# INFO:canopy.load_study_job:Loading job index 280
# INFO:canopy.load_study_job:Loading job index 281
# INFO:canopy.load_study_job:Loading job index 282
# INFO:canopy.load_study_job:Loading job index 283
# INFO:canopy.load_study_job:Loading job index 284
# INFO:canopy.load_study_job:Loading job index 285
# INFO:canopy.load_study_job:Loading job index 286
# INFO:canopy.load_study_job:Loading job index 287
# INFO:canopy.load_study_job:Loading job index 288
# INFO:canopy.load_study_job:Loading job index 289
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 290
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 291
# INFO:canopy.load_study_job:Loading job index 292
# INFO:canopy.load_study_job:Loading job index 293
# INFO:canopy.load_study_job:Loading job index 294
# INFO:canopy.load_study_job:Loading job index 295
# INFO:canopy.load_study_job:Loading job index 296
# INFO:canopy.load_study_job:Loading job index 297
# INFO:canopy.load_study_job:Loading job index 298
# INFO:canopy.load_study_job:Loading job index 299
# INFO:canopy.load_study_job:Loading job index 300
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 301
# INFO:canopy.load_study_job:Loading job index 302
# INFO:canopy.load_study_job:Loading job index 303
# INFO:canopy.load_study_job:Loading job index 304
# INFO:canopy.load_study_job:Loading job index 305
# INFO:canopy.load_study_job:Loading job index 306
# INFO:canopy.load_study_job:Loading job index 307
# INFO:canopy.load_study_job:Loading job index 308
# INFO:canopy.load_study_job:Loading job index 309
# INFO:canopy.load_study_job:Loading job index 310
# INFO:canopy.load_study_job:Loading job index 311
# INFO:canopy.load_study_job:Loading job index 312
# INFO:canopy.load_study_job:Loading job index 313
# INFO:canopy.load_study_job:Loading job index 314
# INFO:canopy.load_study_job:Loading job index 315
# INFO:canopy.load_study_job:Loading job index 316
# INFO:canopy.load_study_job:Loading job index 317
# INFO:canopy.load_study_job:Loading job index 318
# INFO:canopy.load_study_job:Loading job index 319
# INFO:canopy.load_study_job:Loading job index 320
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 321
# INFO:canopy.load_study_job:Loading job index 322
# INFO:canopy.load_study_job:Loading job index 323
# INFO:canopy.load_study_job:Loading job index 324
# INFO:canopy.load_study_job:Loading job index 325
# INFO:canopy.load_study_job:Loading job index 326
# INFO:canopy.load_study_job:Loading job index 327
# INFO:canopy.load_study_job:Loading job index 328
# INFO:canopy.load_study_job:Loading job index 329
# INFO:canopy.load_study_job:Loading job index 330
# INFO:canopy.load_study_job:Loading job index 331
# INFO:canopy.load_study_job:Loading job index 332
# INFO:canopy.load_study_job:Loading job index 333
# INFO:canopy.load_study_job:Loading job index 334
# INFO:canopy.load_study_job:Loading job index 335
# INFO:canopy.load_study_job:Loading job index 336
# INFO:canopy.load_study_job:Loading job index 337
# INFO:canopy.load_study_job:Loading job index 338
# INFO:canopy.load_study_job:Loading job index 339
# INFO:canopy.load_study_job:Loading job index 340
# INFO:canopy.load_study_job:Loading job index 341
# INFO:canopy.load_study_job:Loading job index 342
# INFO:canopy.load_study_job:Loading job index 343
# INFO:canopy.load_study_job:Loading job index 344
# INFO:canopy.load_study_job:Loading job index 345
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 346
# INFO:canopy.load_study_job:Loading job index 347
# INFO:canopy.load_study_job:Loading job index 348
# INFO:canopy.load_study_job:Loading job index 349
# INFO:canopy.load_study_job:Loading job index 350
# INFO:canopy.load_study_job:Loading job index 351
# INFO:canopy.load_study_job:Loading job index 352
# INFO:canopy.load_study_job:Loading job index 353
# INFO:canopy.load_study_job:Loading job index 354
# INFO:canopy.load_study_job:Loading job index 355
# INFO:canopy.load_study_job:Loading job index 356
# INFO:canopy.load_study_job:Loading job index 357
# INFO:canopy.load_study_job:Loading job index 358
# INFO:canopy.load_study_job:Loading job index 359
# INFO:canopy.load_study_job:Loading job index 360
# INFO:canopy.load_study_job:Loading job index 361
# INFO:canopy.load_study_job:Loading job index 362
# INFO:canopy.load_study_job:Loading job index 363
# INFO:canopy.load_study_job:Loading job index 364
# INFO:canopy.load_study_job:Loading job index 365
# INFO:canopy.load_study_job:Loading job index 366
# INFO:canopy.load_study_job:Loading job index 367
# INFO:canopy.load_study_job:Loading job index 368
# INFO:canopy.load_study_job:Loading job index 369
# INFO:canopy.load_study_job:Loading job index 370
# INFO:canopy.load_study_job:Loading job index 371
# INFO:canopy.load_study_job:Loading job index 372
# INFO:canopy.load_study_job:Loading job index 373
# INFO:canopy.load_study_job:Loading job index 374
# INFO:canopy.load_study_job:Loading job index 375
# INFO:canopy.load_study_job:Loading job index 376
# INFO:canopy.load_study_job:Loading job index 377
# INFO:canopy.load_study_job:Loading job index 378
# INFO:canopy.load_study_job:Loading job index 379
# INFO:canopy.load_study_job:Loading job index 380
# INFO:canopy.load_study_job:Loading job index 381
# INFO:canopy.load_study_job:Loading job index 382
# INFO:canopy.load_study_job:Loading job index 383
# INFO:canopy.load_study_job:Loading job index 384
# INFO:canopy.load_study_job:Loading job index 385
# INFO:canopy.load_study_job:Loading job index 386
# INFO:canopy.load_study_job:Loading job index 387
# INFO:canopy.load_study_job:Loading job index 388
# INFO:canopy.load_study_job:Loading job index 389
# INFO:canopy.load_study_job:Loading job index 390
# INFO:canopy.load_study_job:Loading job index 391
# INFO:canopy.load_study_job:Loading job index 392
# INFO:canopy.load_study_job:Loading job index 393
# INFO:canopy.load_study_job:Loading job index 394
# INFO:canopy.load_study_job:Loading job index 395
# INFO:canopy.load_study_job:Loading job index 396
# INFO:canopy.load_study_job:Loading job index 397
# INFO:canopy.load_study_job:Loading job index 398
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 399
# INFO:canopy.load_study_job:Loading job index 400
# INFO:canopy.load_study_job:Loading job index 401
# INFO:canopy.load_study_job:Loading job index 402
# INFO:canopy.load_study_job:Loading job index 403
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 404
# INFO:canopy.load_study_job:Loading job index 405
# INFO:canopy.load_study_job:Loading job index 406
# INFO:canopy.load_study_job:Loading job index 407
# INFO:canopy.load_study_job:Loading job index 408
# INFO:canopy.load_study_job:Loading job index 409
# INFO:canopy.load_study_job:Loading job index 410
# INFO:canopy.load_study_job:Loading job index 411
# INFO:canopy.load_study_job:Loading job index 412
# INFO:canopy.load_study_job:Loading job index 413
# INFO:canopy.load_study_job:Loading job index 414
# INFO:canopy.load_study_job:Loading job index 415
# INFO:canopy.load_study_job:Loading job index 416
# INFO:canopy.load_study_job:Loading job index 417
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 418
# INFO:canopy.load_study_job:Loading job index 419
# INFO:canopy.load_study_job:Loading job index 420
# INFO:canopy.load_study_job:Loading job index 421
# INFO:canopy.load_study_job:Loading job index 422
# INFO:canopy.load_study_job:Loading job index 423
# INFO:canopy.load_study_job:Loading job index 424
# INFO:canopy.load_study_job:Loading job index 425
# INFO:canopy.load_study_job:Loading job index 426
# INFO:canopy.load_study_job:Loading job index 427
# INFO:canopy.load_study_job:Loading job index 428
# INFO:canopy.load_study_job:Loading job index 429
# INFO:canopy.load_study_job:Loading job index 430
# INFO:canopy.load_study_job:Loading job index 431
# INFO:canopy.load_study_job:Loading job index 432
# INFO:canopy.load_study_job:Loading job index 433
# INFO:canopy.load_study_job:Loading job index 434
# INFO:canopy.load_study_job:Loading job index 435
# INFO:canopy.load_study_job:Loading job index 436
# INFO:canopy.load_study_job:Loading job index 437
# INFO:canopy.load_study_job:Loading job index 438
# INFO:canopy.load_study_job:Loading job index 439
# INFO:canopy.load_study_job:Loading job index 440
# INFO:canopy.load_study_job:Loading job index 441
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 442
# INFO:canopy.load_study_job:Loading job index 443
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 444
# INFO:canopy.load_study_job:Loading job index 445
# INFO:canopy.load_study_job:Loading job index 446
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 447
# INFO:canopy.load_study_job:Loading job index 448
# INFO:canopy.load_study_job:Loading job index 449
# INFO:canopy.load_study_job:Loading job index 450
# INFO:canopy.load_study_job:Loading job index 451
# INFO:canopy.load_study_job:Loading job index 452
# INFO:canopy.load_study_job:Loading job index 453
# INFO:canopy.load_study_job:Loading job index 454
# INFO:canopy.load_study_job:Loading job index 455
# INFO:canopy.load_study_job:Loading job index 456
# INFO:canopy.load_study_job:Loading job index 457
# INFO:canopy.load_study_job:Loading job index 458
# INFO:canopy.load_study_job:Loading job index 459
# INFO:canopy.load_study_job:Loading job index 460
# INFO:canopy.load_study_job:Loading job index 461
# INFO:canopy.load_study_job:Loading job index 462
# INFO:canopy.load_study_job:Loading job index 463
# INFO:canopy.load_study_job:Loading job index 464
# INFO:canopy.load_study_job:Loading job index 465
# INFO:canopy.load_study_job:Loading job index 466
# INFO:canopy.load_study_job:Loading job index 467
# INFO:canopy.load_study_job:Loading job index 468
# INFO:canopy.load_study_job:Loading job index 469
# INFO:canopy.load_study_job:Loading job index 470
# INFO:canopy.load_study_job:Loading job index 471
# INFO:canopy.load_study_job:Loading job index 472
# INFO:canopy.load_study_job:Loading job index 473
# INFO:canopy.load_study_job:Loading job index 474
# INFO:canopy.load_study_job:Loading job index 475
# INFO:canopy.load_study_job:Loading job index 476
# INFO:canopy.load_study_job:Loading job index 477
# INFO:canopy.load_study_job:Loading job index 478
# INFO:canopy.load_study_job:Loading job index 479
# INFO:canopy.load_study_job:Loading job index 480
# INFO:canopy.load_study_job:Loading job index 481
# INFO:canopy.load_study_job:Loading job index 482
# INFO:canopy.load_study_job:Loading job index 483
# INFO:canopy.load_study_job:Loading job index 484
# INFO:canopy.load_study_job:Loading job index 485
# INFO:canopy.load_study_job:Loading job index 486
# INFO:canopy.load_study_job:Loading job index 487
# INFO:canopy.load_study_job:Loading job index 488
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 489
# INFO:canopy.load_study_job:Loading job index 490
# INFO:canopy.load_study_job:Loading job index 491
# INFO:canopy.load_study_job:Loading job index 492
# INFO:canopy.load_study_job:Loading job index 493
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 494
# INFO:canopy.load_study_job:Loading job index 495
# INFO:canopy.load_study_job:Loading job index 496
# INFO:canopy.load_study_job:Loading job index 497
# INFO:canopy.load_study_job:Loading job index 498
# INFO:canopy.load_study_job:Loading job index 499
# INFO:canopy.load_study_job:Loading job index 500
# INFO:canopy.load_study_job:Loading job index 501
# INFO:canopy.load_study_job:Loading job index 502
# INFO:canopy.load_study_job:Loading job index 503
# INFO:canopy.load_study_job:Loading job index 504
# INFO:canopy.load_study_job:Loading job index 505
# INFO:canopy.load_study_job:Loading job index 506
# INFO:canopy.load_study_job:Loading job index 507
# INFO:canopy.load_study_job:Loading job index 508
# INFO:canopy.load_study_job:Loading job index 509
# INFO:canopy.load_study_job:Loading job index 510
# INFO:canopy.load_study_job:Loading job index 511
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 512
# INFO:canopy.load_study_job:Loading job index 513
# INFO:canopy.load_study_job:Loading job index 514
# INFO:canopy.load_study_job:Loading job index 515
# INFO:canopy.load_study_job:Loading job index 516
# INFO:canopy.load_study_job:Loading job index 517
# INFO:canopy.load_study_job:Loading job index 518
# INFO:canopy.load_study_job:Loading job index 519
# INFO:canopy.load_study_job:Loading job index 520
# INFO:canopy.load_study_job:Loading job index 521
# INFO:canopy.load_study_job:Loading job index 522
# INFO:canopy.load_study_job:Loading job index 523
# INFO:canopy.load_study_job:Loading job index 524
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 525
# INFO:canopy.load_study_job:Loading job index 526
# INFO:canopy.load_study_job:Loading job index 527
# INFO:canopy.load_study_job:Loading job index 528
# INFO:canopy.load_study_job:Loading job index 529
# INFO:canopy.load_study_job:Loading job index 530
# INFO:canopy.load_study_job:Loading job index 531
# INFO:canopy.load_study_job:Loading job index 532
# INFO:canopy.load_study_job:Loading job index 533
# INFO:canopy.load_study_job:Loading job index 534
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 535
# INFO:canopy.load_study_job:Loading job index 536
# INFO:canopy.load_study_job:Loading job index 537
# INFO:canopy.load_study_job:Loading job index 538
# INFO:canopy.load_study_job:Loading job index 539
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 540
# INFO:canopy.load_study_job:Loading job index 541
# INFO:canopy.load_study_job:Loading job index 542
# INFO:canopy.load_study_job:Loading job index 543
# INFO:canopy.load_study_job:Loading job index 544
# INFO:canopy.load_study_job:Loading job index 545
# INFO:canopy.load_study_job:Loading job index 546
# INFO:canopy.load_study_job:Loading job index 547
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 548
# INFO:canopy.load_study_job:Loading job index 549
# INFO:canopy.load_study_job:Loading job index 550
# INFO:canopy.load_study_job:Loading job index 551
# INFO:canopy.load_study_job:Loading job index 552
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 553
# INFO:canopy.load_study_job:Loading job index 554
# INFO:canopy.load_study_job:Loading job index 555
# INFO:canopy.load_study_job:Loading job index 556
# INFO:canopy.load_study_job:Loading job index 557
# INFO:canopy.load_study_job:Loading job index 558
# INFO:canopy.load_study_job:Loading job index 559
# INFO:canopy.load_study_job:Loading job index 560
# INFO:canopy.load_study_job:Loading job index 561
# INFO:canopy.load_study_job:Loading job index 562
# INFO:canopy.load_study_job:Loading job index 563
# INFO:canopy.load_study_job:Loading job index 564
# INFO:canopy.load_study_job:Loading job index 565
# INFO:canopy.load_study_job:Loading job index 566
# INFO:canopy.load_study_job:Loading job index 567
# INFO:canopy.load_study_job:Loading job index 568
# INFO:canopy.load_study_job:Loading job index 569
# INFO:canopy.load_study_job:Loading job index 570
# INFO:canopy.load_study_job:Loading job index 571
# INFO:canopy.load_study_job:Loading job index 572
# INFO:canopy.load_study_job:Loading job index 573
# INFO:canopy.load_study_job:Loading job index 574
# INFO:canopy.load_study_job:Loading job index 575
# INFO:canopy.load_study_job:Loading job index 576
# INFO:canopy.load_study_job:Loading job index 577
# INFO:canopy.load_study_job:Loading job index 578
# INFO:canopy.load_study_job:Loading job index 579
# INFO:canopy.load_study_job:Loading job index 580
# INFO:canopy.load_study_job:Loading job index 581
# INFO:canopy.load_study_job:Loading job index 582
# INFO:canopy.load_study_job:Loading job index 583
# INFO:canopy.load_study_job:Loading job index 584
# INFO:canopy.load_study_job:Loading job index 585
# INFO:canopy.load_study_job:Loading job index 586
# INFO:canopy.load_study_job:Loading job index 587
# INFO:canopy.load_study_job:Loading job index 588
# INFO:canopy.load_study_job:Loading job index 589
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 590
# INFO:canopy.load_study_job:Loading job index 591
# INFO:canopy.load_study_job:Loading job index 592
# INFO:canopy.load_study_job:Loading job index 593
# INFO:canopy.load_study_job:Loading job index 594
# INFO:canopy.load_study_job:Loading job index 595
# INFO:canopy.load_study_job:Loading job index 596
# INFO:canopy.load_study_job:Loading job index 597
# INFO:canopy.load_study_job:Loading job index 598
# INFO:canopy.load_study_job:Loading job index 599
# INFO:canopy.load_study_job:Loading job index 600
# INFO:canopy.load_study_job:Loading job index 601
# INFO:canopy.load_study_job:Loading job index 602
# INFO:canopy.load_study_job:Loading job index 603
# INFO:canopy.load_study_job:Loading job index 604
# INFO:canopy.load_study_job:Loading job index 605
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 606
# INFO:canopy.load_study_job:Loading job index 607
# INFO:canopy.load_study_job:Loading job index 608
# INFO:canopy.load_study_job:Loading job index 609
# INFO:canopy.load_study_job:Loading job index 610
# INFO:canopy.load_study_job:Loading job index 611
# INFO:canopy.load_study_job:Loading job index 612
# INFO:canopy.load_study_job:Loading job index 613
# INFO:canopy.load_study_job:Loading job index 614
# INFO:canopy.load_study_job:Loading job index 615
# INFO:canopy.load_study_job:Loading job index 616
# INFO:canopy.load_study_job:Loading job index 617
# INFO:canopy.load_study_job:Loading job index 618
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 619
# INFO:canopy.load_study_job:Loading job index 620
# INFO:canopy.load_study_job:Loading job index 621
# INFO:canopy.load_study_job:Loading job index 622
# INFO:canopy.load_study_job:Loading job index 623
# INFO:canopy.load_study_job:Loading job index 624
# INFO:canopy.load_study_job:Loading job index 625
# INFO:canopy.load_study_job:Loading job index 626
# INFO:canopy.load_study_job:Loading job index 627
# INFO:canopy.load_study_job:Loading job index 628
# INFO:canopy.load_study_job:Loading job index 629
# INFO:canopy.load_study_job:Loading job index 630
# INFO:canopy.load_study_job:Loading job index 631
# INFO:canopy.load_study_job:Loading job index 632
# INFO:canopy.load_study_job:Loading job index 633
# INFO:canopy.load_study_job:Loading job index 634
# INFO:canopy.load_study_job:Loading job index 635
# INFO:canopy.load_study_job:Loading job index 636
# INFO:canopy.load_study_job:Loading job index 637
# INFO:canopy.load_study_job:Loading job index 638
# INFO:canopy.load_study_job:Loading job index 639
# INFO:canopy.load_study_job:Loading job index 640
# INFO:canopy.load_study_job:Loading job index 641
# INFO:canopy.load_study_job:Loading job index 642
# INFO:canopy.load_study_job:Loading job index 643
# INFO:canopy.load_study_job:Loading job index 644
# INFO:canopy.load_study_job:Loading job index 645
# INFO:canopy.load_study_job:Loading job index 646
# INFO:canopy.load_study_job:Loading job index 647
# INFO:canopy.load_study_job:Loading job index 648
# INFO:canopy.load_study_job:Loading job index 649
# INFO:canopy.load_study_job:Loading job index 650
# INFO:canopy.load_study_job:Loading job index 651
# INFO:canopy.load_study_job:Loading job index 652
# INFO:canopy.load_study_job:Loading job index 653
# INFO:canopy.load_study_job:Loading job index 654
# INFO:canopy.load_study_job:Loading job index 655
# INFO:canopy.load_study_job:Loading job index 656
# INFO:canopy.load_study_job:Loading job index 657
# INFO:canopy.load_study_job:Loading job index 658
# INFO:canopy.load_study_job:Loading job index 659
# INFO:canopy.load_study_job:Loading job index 660
# INFO:canopy.load_study_job:Loading job index 661
# INFO:canopy.load_study_job:Loading job index 662
# INFO:canopy.load_study_job:Loading job index 663
# INFO:canopy.load_study_job:Loading job index 664
# INFO:canopy.load_study_job:Loading job index 665
# INFO:canopy.load_study_job:Loading job index 666
# INFO:canopy.load_study_job:Loading job index 667
# INFO:canopy.load_study_job:Loading job index 668
# INFO:canopy.load_study_job:Loading job index 669
# INFO:canopy.load_study_job:Loading job index 670
# INFO:canopy.load_study_job:Loading job index 671
# INFO:canopy.load_study_job:Loading job index 672
# INFO:canopy.load_study_job:Loading job index 673
# INFO:canopy.load_study_job:Loading job index 674
# INFO:canopy.load_study_job:Loading job index 675
# INFO:canopy.load_study_job:Loading job index 676
# INFO:canopy.load_study_job:Loading job index 677
# INFO:canopy.load_study_job:Loading job index 678
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 679
# INFO:canopy.load_study_job:Loading job index 680
# INFO:canopy.load_study_job:Loading job index 681
# INFO:canopy.load_study_job:Loading job index 682
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 683
# INFO:canopy.load_study_job:Loading job index 684
# INFO:canopy.load_study_job:Loading job index 685
# INFO:canopy.load_study_job:Loading job index 686
# INFO:canopy.load_study_job:Loading job index 687
# INFO:canopy.load_study_job:Loading job index 688
# INFO:canopy.load_study_job:Loading job index 689
# INFO:canopy.load_study_job:Loading job index 690
# INFO:canopy.load_study_job:Loading job index 691
# INFO:canopy.load_study_job:Loading job index 692
# INFO:canopy.load_study_job:Loading job index 693
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 694
# INFO:canopy.load_study_job:Loading job index 695
# INFO:canopy.load_study_job:Loading job index 696
# INFO:canopy.load_study_job:Loading job index 697
# INFO:canopy.load_study_job:Loading job index 698
# INFO:canopy.load_study_job:Loading job index 699
# INFO:canopy.load_study_job:Loading job index 700
# INFO:canopy.load_study_job:Loading job index 701
# INFO:canopy.load_study_job:Loading job index 702
# INFO:canopy.load_study_job:Loading job index 703
# INFO:canopy.load_study_job:Loading job index 704
# INFO:canopy.load_study_job:Loading job index 705
# INFO:canopy.load_study_job:Loading job index 706
# INFO:canopy.load_study_job:Loading job index 707
# INFO:canopy.load_study_job:Loading job index 708
# INFO:canopy.load_study_job:Loading job index 709
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 710
# INFO:canopy.load_study_job:Loading job index 711
# INFO:canopy.load_study_job:Loading job index 712
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 713
# INFO:canopy.load_study_job:Loading job index 714
# INFO:canopy.load_study_job:Loading job index 715
# INFO:canopy.load_study_job:Loading job index 716
# INFO:canopy.load_study_job:Loading job index 717
# INFO:canopy.load_study_job:Loading job index 718
# INFO:canopy.load_study_job:Loading job index 719
# INFO:canopy.load_study_job:Loading job index 720
# INFO:canopy.load_study_job:Loading job index 721
# INFO:canopy.load_study_job:Loading job index 722
# INFO:canopy.load_study_job:Loading job index 723
# INFO:canopy.load_study_job:Loading job index 724
# INFO:canopy.load_study_job:Loading job index 725
# INFO:canopy.load_study_job:Loading job index 726
# INFO:canopy.load_study_job:Loading job index 727
# INFO:canopy.load_study_job:Loading job index 728
# INFO:canopy.load_study_job:Loading job index 729
# INFO:canopy.load_study_job:Loading job index 730
# INFO:canopy.load_study_job:Loading job index 731
# INFO:canopy.load_study_job:Loading job index 732
# INFO:canopy.load_study_job:Loading job index 733
# INFO:canopy.load_study_job:Loading job index 734
# INFO:canopy.load_study_job:Loading job index 735
# INFO:canopy.load_study_job:Loading job index 736
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 737
# INFO:canopy.load_study_job:Loading job index 738
# INFO:canopy.load_study_job:Loading job index 739
# ...
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-768.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-768.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-768.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-777.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-777.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-777.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-777.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-777.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-777.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-777.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-777.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-777.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-777.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-799.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-799.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-799.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-799.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-799.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-799.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-799.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-799.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-799.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-799.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-817.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-817.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-817.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-817.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-817.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-817.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-817.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-817.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-817.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-817.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-819.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-819.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-819.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-819.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-819.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-819.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-819.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-819.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-819.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-819.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-823.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-823.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-823.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-823.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-823.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-823.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-823.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-823.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-823.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-823.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-828.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-828.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-828.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-828.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-828.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-828.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-828.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-828.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-828.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-828.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-835.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-835.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-835.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-835.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-835.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-835.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-835.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-835.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-835.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-835.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-844.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-844.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-844.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-844.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-844.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-844.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-844.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-844.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-844.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-844.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-853.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-853.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-853.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-853.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-853.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-853.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-853.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-853.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-853.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-853.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-854.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-854.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-854.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-854.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-854.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-854.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-854.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-854.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-854.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-854.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-861.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-861.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-861.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-861.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-861.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-861.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-861.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-861.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-861.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-861.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-868.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-868.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-868.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-868.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-868.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-868.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-868.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-868.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-868.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-868.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-870.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-870.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-870.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-870.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-870.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-870.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-870.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-870.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-870.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-870.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-884.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-884.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-884.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-884.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-884.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-884.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-884.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-884.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-884.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-884.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-940.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-940.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-940.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-940.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-940.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-940.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-940.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-940.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-940.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-940.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-951.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-951.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-951.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-951.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-951.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-951.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-951.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-951.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-951.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-951.
# Warning: Scalar 'RaceEng_EBottoming' not found in job 48fda98fb8a44663b831df56272bb99f-966.
# Warning: Scalar 'RaceEng_UndersteerT10Entry' not found in job 48fda98fb8a44663b831df56272bb99f-966.
# Warning: Scalar 'RaceEng_UndersteerT9' not found in job 48fda98fb8a44663b831df56272bb99f-966.
# Warning: Scalar 'RaceEng_aCamberFEOS' not found in job 48fda98fb8a44663b831df56272bb99f-966.
# Warning: Scalar 'RaceEng_aCamberREOS' not found in job 48fda98fb8a44663b831df56272bb99f-966.
# Warning: Scalar 'RaceEng_kHeaveF' not found in job 48fda98fb8a44663b831df56272bb99f-966.
# Warning: Scalar 'RaceEng_kHeaveR' not found in job 48fda98fb8a44663b831df56272bb99f-966.
# Warning: Scalar 'RaceEng_kRoll' not found in job 48fda98fb8a44663b831df56272bb99f-966.
# Warning: Scalar 'RaceEng_rBrakeBalHighPressure' not found in job 48fda98fb8a44663b831df56272bb99f-966.
# Warning: Scalar 'tLapTotal' not found in job 48fda98fb8a44663b831df56272bb99f-966.

# %% [markdown]
# ## Check the disqualified jobs

# %%
disqualified_jobs_data = get_disqualified_jobs_data_in_study_with_id_due_to_scalar_limit_violations(
    scalar_data=scalar_data
)

print(disqualified_jobs_data)

#Get the number of disqualified jobs
disqualified_jobs_count = len(disqualified_jobs_data.keys())
print(f"Number of disqualified jobs: {disqualified_jobs_count}")
# Out:
# {'48fda98fb8a44663b831df56272bb99f-1': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 0.716151, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.002462, 'min_limit': -0.0015, 'max_limit': inf}], '48fda98fb8a44663b831df56272bb99f-2': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 1.228417, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.010127, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.004248, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': -1.852298, 'min_limit': -1.5, 'max_limit': 0.0}], '48fda98fb8a44663b831df56272bb99f-3': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 1.464386, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': 0.289176, 'min_limit': -1.5, 'max_limit': 0.0}], '48fda98fb8a44663b831df56272bb99f-4': [{'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.009693, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.006954, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberFEOS', 'scalar_value': 3.099193, 'min_limit': -3.5, 'max_limit': 0.0}], '48fda98fb8a44663b831df56272bb99f-5': [{'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.003784, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberFEOS', 'scalar_value': 0.562457, 'min_limit': -3.5, 'max_limit': 0.0}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': 0.909448, 'min_limit': -1.5, 'max_limit': 0.0}], '48fda98fb8a44663b831df56272bb99f-6': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 1.489772, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.009789, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.006568, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberFEOS', 'scalar_value': 3.352101, 'min_limit': -3.5, 'max_limit': 0.0}], '48fda98fb8a44663b831df56272bb99f-7': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 1.13942, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.004742, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.004738, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberFEOS', 'scalar_value': 1.806417, 'min_limit': -3.5, 'max_limit': 0.0}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': 0.121911, 'min_limit': -1.5, 'max_limit': 0.0}], '48fda98fb8a44663b831df56272bb99f-8': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 0.635154, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.009904, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberFEOS', 'scalar_value': -3.963766, 'min_limit': -3.5, 'max_limit': 0.0}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': -3.79425, 'min_limit': -1.5, 'max_limit': 0.0}], '48fda98fb8a44663b831df56272bb99f-9': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 0.819815, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10Entry', 'scalar_value': -0.010429, 'min_limit': -0.004, 'max_limit': inf}, {'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.006655, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberFEOS', 'scalar_value': 1.138401, 'min_limit': -3.5, 'max_limit': 0.0}, {'scalar': 'RaceEng_aCamberREOS', 'scalar_value': -1.941761, 'min_limit': -1.5, 'max_limit': 0.0}], '48fda98fb8a44663b831df56272bb99f-10': [{'scalar': 'RaceEng_UndersteerT9', 'scalar_value': -0.004472, 'min_limit': -0.0015, 'max_limit': inf}, {'scalar': 'RaceEng_aCamberFEOS', 'scalar_value': 0.947155, 'min_limit': -3.5, 'max_limit': 0.0}], '48fda98fb8a44663b831df56272bb99f-11': [{'scalar': 'RaceEng_EBottoming', 'scalar_value': 0.796985, 'min_limit': -inf, 'max_limit': 0.5}, {'scalar': 'RaceEng_UndersteerT10E ...
# Number of disqualified jobs: 929

# %% [markdown]
# ## Get the job with the minimum tLapTotal

# %%
# Create a list of job_ids to exclude from the analysis from the keys of disqualified_jobs_data
excluded_job_ids = list(disqualified_jobs_data.keys())

results = await get_job_with_minimum_scalar_value(
    session=session,
    study_id=study_id,
    sim_type='DynamicLap',
    scalar_name='tLapTotal',
    excluded_job_ids=excluded_job_ids
)

print(results)
# Out:
# INFO:canopy.load_study_job:Loading job index 0
# INFO:canopy.load_study_job:Loading job index 1
# INFO:canopy.load_study_job:Loading job index 2
# INFO:canopy.load_study_job:Loading job index 3
# INFO:canopy.load_study_job:Loading job index 4
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 5
# INFO:canopy.load_study_job:Loading job index 6
# INFO:canopy.load_study_job:Loading job index 7
# INFO:canopy.load_study_job:Loading job index 8
# INFO:canopy.load_study_job:Loading job index 9
# INFO:canopy.load_study_job:Loading job index 10
# INFO:canopy.load_study_job:Loading job index 11
# INFO:canopy.load_study_job:Loading job index 12
# INFO:canopy.load_study_job:Loading job index 13
# INFO:canopy.load_study_job:Loading job index 14
# INFO:canopy.load_study_job:Loading job index 15
# INFO:canopy.load_study_job:Loading job index 16
# INFO:canopy.load_study_job:Loading job index 17
# INFO:canopy.load_study_job:Loading job index 18
# INFO:canopy.load_study_job:Loading job index 19
# INFO:canopy.load_study_job:Loading job index 20
# INFO:canopy.load_study_job:Loading job index 21
# INFO:canopy.load_study_job:Loading job index 22
# INFO:canopy.load_study_job:Loading job index 23
# INFO:canopy.load_study_job:Loading job index 24
# INFO:canopy.load_study_job:Loading job index 25
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 26
# INFO:canopy.load_study_job:Loading job index 27
# INFO:canopy.load_study_job:Loading job index 28
# INFO:canopy.load_study_job:Loading job index 29
# INFO:canopy.load_study_job:Loading job index 30
# INFO:canopy.load_study_job:Loading job index 31
# INFO:canopy.load_study_job:Loading job index 32
# INFO:canopy.load_study_job:Loading job index 33
# INFO:canopy.load_study_job:Loading job index 34
# INFO:canopy.load_study_job:Loading job index 35
# INFO:canopy.load_study_job:Loading job index 36
# INFO:canopy.load_study_job:Loading job index 37
# INFO:canopy.load_study_job:Loading job index 38
# INFO:canopy.load_study_job:Loading job index 39
# INFO:canopy.load_study_job:Loading job index 40
# INFO:canopy.load_study_job:Loading job index 41
# INFO:canopy.load_study_job:Loading job index 42
# INFO:canopy.load_study_job:Loading job index 43
# INFO:canopy.load_study_job:Loading job index 44
# INFO:canopy.load_study_job:Loading job index 45
# INFO:canopy.load_study_job:Loading job index 46
# INFO:canopy.load_study_job:Loading job index 47
# INFO:canopy.load_study_job:Loading job index 48
# INFO:canopy.load_study_job:Loading job index 49
# INFO:canopy.load_study_job:Loading job index 50
# INFO:canopy.load_study_job:Loading job index 51
# INFO:canopy.load_study_job:Loading job index 52
# INFO:canopy.load_study_job:Loading job index 53
# INFO:canopy.load_study_job:Loading job index 54
# INFO:canopy.load_study_job:Loading job index 55
# INFO:canopy.load_study_job:Loading job index 56
# INFO:canopy.load_study_job:Loading job index 57
# INFO:canopy.load_study_job:Loading job index 58
# INFO:canopy.load_study_job:Loading job index 59
# INFO:canopy.load_study_job:Loading job index 60
# INFO:canopy.load_study_job:Loading job index 61
# INFO:canopy.load_study_job:Loading job index 62
# INFO:canopy.load_study_job:Loading job index 63
# INFO:canopy.load_study_job:Loading job index 64
# INFO:canopy.load_study_job:Loading job index 65
# INFO:canopy.load_study_job:Loading job index 66
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 67
# INFO:canopy.load_study_job:Loading job index 68
# INFO:canopy.load_study_job:Loading job index 69
# INFO:canopy.load_study_job:Loading job index 70
# INFO:canopy.load_study_job:Loading job index 71
# INFO:canopy.load_study_job:Loading job index 72
# INFO:canopy.load_study_job:Loading job index 73
# INFO:canopy.load_study_job:Loading job index 74
# INFO:canopy.load_study_job:Loading job index 75
# INFO:canopy.load_study_job:Loading job index 76
# INFO:canopy.load_study_job:Loading job index 77
# INFO:canopy.load_study_job:Loading job index 78
# INFO:canopy.load_study_job:Loading job index 79
# INFO:canopy.load_study_job:Loading job index 80
# INFO:canopy.load_study_job:Loading job index 81
# INFO:canopy.load_study_job:Loading job index 82
# INFO:canopy.load_study_job:Loading job index 83
# INFO:canopy.load_study_job:Loading job index 84
# INFO:canopy.load_study_job:Loading job index 85
# INFO:canopy.load_study_job:Loading job index 86
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 87
# INFO:canopy.load_study_job:Loading job index 88
# INFO:canopy.load_study_job:Loading job index 89
# INFO:canopy.load_study_job:Loading job index 90
# INFO:canopy.load_study_job:Loading job index 91
# INFO:canopy.load_study_job:Loading job index 92
# INFO:canopy.load_study_job:Loading job index 93
# INFO:canopy.load_study_job:Loading job index 94
# INFO:canopy.load_study_job:Loading job index 95
# INFO:canopy.load_study_job:Loading job index 96
# INFO:canopy.load_study_job:Loading job index 97
# INFO:canopy.load_study_job:Loading job index 98
# INFO:canopy.load_study_job:Loading job index 99
# INFO:canopy.load_study_job:Loading job index 100
# INFO:canopy.load_study_job:Loading job index 101
# INFO:canopy.load_study_job:Loading job index 102
# INFO:canopy.load_study_job:Loading job index 103
# INFO:canopy.load_study_job:Loading job index 104
# INFO:canopy.load_study_job:Loading job index 105
# INFO:canopy.load_study_job:Loading job index 106
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 107
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 108
# INFO:canopy.load_study_job:Loading job index 109
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 110
# INFO:canopy.load_study_job:Loading job index 111
# INFO:canopy.load_study_job:Loading job index 112
# INFO:canopy.load_study_job:Loading job index 113
# INFO:canopy.load_study_job:Loading job index 114
# INFO:canopy.load_study_job:Loading job index 115
# INFO:canopy.load_study_job:Loading job index 116
# INFO:canopy.load_study_job:Loading job index 117
# INFO:canopy.load_study_job:Loading job index 118
# INFO:canopy.load_study_job:Loading job index 119
# INFO:canopy.load_study_job:Loading job index 120
# INFO:canopy.load_study_job:Loading job index 121
# INFO:canopy.load_study_job:Loading job index 122
# INFO:canopy.load_study_job:Loading job index 123
# INFO:canopy.load_study_job:Loading job index 124
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 125
# INFO:canopy.load_study_job:Loading job index 126
# INFO:canopy.load_study_job:Loading job index 127
# INFO:canopy.load_study_job:Loading job index 128
# INFO:canopy.load_study_job:Loading job index 129
# INFO:canopy.load_study_job:Loading job index 130
# INFO:canopy.load_study_job:Loading job index 131
# INFO:canopy.load_study_job:Loading job index 132
# INFO:canopy.load_study_job:Loading job index 133
# INFO:canopy.load_study_job:Loading job index 134
# INFO:canopy.load_study_job:Loading job index 135
# INFO:canopy.load_study_job:Loading job index 136
# INFO:canopy.load_study_job:Loading job index 137
# INFO:canopy.load_study_job:Loading job index 138
# INFO:canopy.load_study_job:Loading job index 139
# INFO:canopy.load_study_job:Loading job index 140
# INFO:canopy.load_study_job:Loading job index 141
# INFO:canopy.load_study_job:Loading job index 142
# INFO:canopy.load_study_job:Loading job index 143
# INFO:canopy.load_study_job:Loading job index 144
# INFO:canopy.load_study_job:Loading job index 145
# INFO:canopy.load_study_job:Loading job index 146
# INFO:canopy.load_study_job:Loading job index 147
# INFO:canopy.load_study_job:Loading job index 148
# INFO:canopy.load_study_job:Loading job index 149
# INFO:canopy.load_study_job:Loading job index 150
# INFO:canopy.load_study_job:Loading job index 151
# INFO:canopy.load_study_job:Loading job index 152
# INFO:canopy.load_study_job:Loading job index 153
# INFO:canopy.load_study_job:Loading job index 154
# INFO:canopy.load_study_job:Loading job index 155
# INFO:canopy.load_study_job:Loading job index 156
# INFO:canopy.load_study_job:Loading job index 157
# INFO:canopy.load_study_job:Loading job index 158
# INFO:canopy.load_study_job:Loading job index 159
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 160
# INFO:canopy.load_study_job:Loading job index 161
# INFO:canopy.load_study_job:Loading job index 162
# INFO:canopy.load_study_job:Loading job index 163
# INFO:canopy.load_study_job:Loading job index 164
# INFO:canopy.load_study_job:Loading job index 165
# INFO:canopy.load_study_job:Loading job index 166
# INFO:canopy.load_study_job:Loading job index 167
# INFO:canopy.load_study_job:Loading job index 168
# INFO:canopy.load_study_job:Loading job index 169
# INFO:canopy.load_study_job:Loading job index 170
# INFO:canopy.load_study_job:Loading job index 171
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 172
# INFO:canopy.load_study_job:Loading job index 173
# INFO:canopy.load_study_job:Loading job index 174
# INFO:canopy.load_study_job:Loading job index 175
# INFO:canopy.load_study_job:Loading job index 176
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 177
# INFO:canopy.load_study_job:Loading job index 178
# INFO:canopy.load_study_job:Loading job index 179
# INFO:canopy.load_study_job:Loading job index 180
# INFO:canopy.load_study_job:Loading job index 181
# INFO:canopy.load_study_job:Loading job index 182
# INFO:canopy.load_study_job:Loading job index 183
# INFO:canopy.load_study_job:Loading job index 184
# INFO:canopy.load_study_job:Loading job index 185
# INFO:canopy.load_study_job:Loading job index 186
# INFO:canopy.load_study_job:Loading job index 187
# INFO:canopy.load_study_job:Loading job index 188
# INFO:canopy.load_study_job:Loading job index 189
# INFO:canopy.load_study_job:Loading job index 190
# INFO:canopy.load_study_job:Loading job index 191
# INFO:canopy.load_study_job:Loading job index 192
# INFO:canopy.load_study_job:Loading job index 193
# INFO:canopy.load_study_job:Loading job index 194
# INFO:canopy.load_study_job:Loading job index 195
# INFO:canopy.load_study_job:Loading job index 196
# INFO:canopy.load_study_job:Loading job index 197
# INFO:canopy.load_study_job:Loading job index 198
# INFO:canopy.load_study_job:Loading job index 199
# INFO:canopy.load_study_job:Loading job index 200
# INFO:canopy.load_study_job:Loading job index 201
# INFO:canopy.load_study_job:Loading job index 202
# INFO:canopy.load_study_job:Loading job index 203
# INFO:canopy.load_study_job:Loading job index 204
# INFO:canopy.load_study_job:Loading job index 205
# INFO:canopy.load_study_job:Loading job index 206
# INFO:canopy.load_study_job:Loading job index 207
# INFO:canopy.load_study_job:Loading job index 208
# INFO:canopy.load_study_job:Loading job index 209
# INFO:canopy.load_study_job:Loading job index 210
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 211
# INFO:canopy.load_study_job:Loading job index 212
# INFO:canopy.load_study_job:Loading job index 213
# INFO:canopy.load_study_job:Loading job index 214
# INFO:canopy.load_study_job:Loading job index 215
# INFO:canopy.load_study_job:Loading job index 216
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 217
# INFO:canopy.load_study_job:Loading job index 218
# INFO:canopy.load_study_job:Loading job index 219
# INFO:canopy.load_study_job:Loading job index 220
# INFO:canopy.load_study_job:Loading job index 221
# INFO:canopy.load_study_job:Loading job index 222
# INFO:canopy.load_study_job:Loading job index 223
# INFO:canopy.load_study_job:Loading job index 224
# INFO:canopy.load_study_job:Loading job index 225
# INFO:canopy.load_study_job:Loading job index 226
# INFO:canopy.load_study_job:Loading job index 227
# INFO:canopy.load_study_job:Loading job index 228
# INFO:canopy.load_study_job:Loading job index 229
# INFO:canopy.load_study_job:Loading job index 230
# INFO:canopy.load_study_job:Loading job index 231
# INFO:canopy.load_study_job:Loading job index 232
# INFO:canopy.load_study_job:Loading job index 233
# INFO:canopy.load_study_job:Loading job index 234
# INFO:canopy.load_study_job:Loading job index 235
# INFO:canopy.load_study_job:Loading job index 236
# INFO:canopy.load_study_job:Loading job index 237
# INFO:canopy.load_study_job:Loading job index 238
# INFO:canopy.load_study_job:Loading job index 239
# INFO:canopy.load_study_job:Loading job index 240
# INFO:canopy.load_study_job:Loading job index 241
# INFO:canopy.load_study_job:Loading job index 242
# INFO:canopy.load_study_job:Loading job index 243
# INFO:canopy.load_study_job:Loading job index 244
# INFO:canopy.load_study_job:Loading job index 245
# INFO:canopy.load_study_job:Loading job index 246
# INFO:canopy.load_study_job:Loading job index 247
# INFO:canopy.load_study_job:Loading job index 248
# INFO:canopy.load_study_job:Loading job index 249
# INFO:canopy.load_study_job:Loading job index 250
# INFO:canopy.load_study_job:Loading job index 251
# INFO:canopy.load_study_job:Loading job index 252
# INFO:canopy.load_study_job:Loading job index 253
# INFO:canopy.load_study_job:Loading job index 254
# INFO:canopy.load_study_job:Loading job index 255
# INFO:canopy.load_study_job:Loading job index 256
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 257
# INFO:canopy.load_study_job:Loading job index 258
# INFO:canopy.load_study_job:Loading job index 259
# INFO:canopy.load_study_job:Loading job index 260
# INFO:canopy.load_study_job:Loading job index 261
# INFO:canopy.load_study_job:Loading job index 262
# INFO:canopy.load_study_job:Loading job index 263
# INFO:canopy.load_study_job:Loading job index 264
# INFO:canopy.load_study_job:Loading job index 265
# INFO:canopy.load_study_job:Loading job index 266
# INFO:canopy.load_study_job:Loading job index 267
# INFO:canopy.load_study_job:Loading job index 268
# INFO:canopy.load_study_job:Loading job index 269
# INFO:canopy.load_study_job:Loading job index 270
# INFO:canopy.load_study_job:Loading job index 271
# INFO:canopy.load_study_job:Loading job index 272
# INFO:canopy.load_study_job:Loading job index 273
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 274
# INFO:canopy.load_study_job:Loading job index 275
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 276
# INFO:canopy.load_study_job:Loading job index 277
# INFO:canopy.load_study_job:Loading job index 278
# INFO:canopy.load_study_job:Loading job index 279
# INFO:canopy.load_study_job:Loading job index 280
# INFO:canopy.load_study_job:Loading job index 281
# INFO:canopy.load_study_job:Loading job index 282
# INFO:canopy.load_study_job:Loading job index 283
# INFO:canopy.load_study_job:Loading job index 284
# INFO:canopy.load_study_job:Loading job index 285
# INFO:canopy.load_study_job:Loading job index 286
# INFO:canopy.load_study_job:Loading job index 287
# INFO:canopy.load_study_job:Loading job index 288
# INFO:canopy.load_study_job:Loading job index 289
# INFO:canopy.load_study_job:Loading job index 290
# INFO:canopy.load_study_job:Loading job index 291
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 292
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 293
# INFO:canopy.load_study_job:Loading job index 294
# INFO:canopy.load_study_job:Loading job index 295
# INFO:canopy.load_study_job:Loading job index 296
# INFO:canopy.load_study_job:Loading job index 297
# INFO:canopy.load_study_job:Loading job index 298
# INFO:canopy.load_study_job:Loading job index 299
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 300
# INFO:canopy.load_study_job:Loading job index 301
# INFO:canopy.load_study_job:Loading job index 302
# INFO:canopy.load_study_job:Loading job index 303
# INFO:canopy.load_study_job:Loading job index 304
# INFO:canopy.load_study_job:Loading job index 305
# INFO:canopy.load_study_job:Loading job index 306
# INFO:canopy.load_study_job:Loading job index 307
# INFO:canopy.load_study_job:Loading job index 308
# INFO:canopy.load_study_job:Loading job index 309
# INFO:canopy.load_study_job:Loading job index 310
# INFO:canopy.load_study_job:Loading job index 311
# INFO:canopy.load_study_job:Loading job index 312
# INFO:canopy.load_study_job:Loading job index 313
# INFO:canopy.load_study_job:Loading job index 314
# INFO:canopy.load_study_job:Loading job index 315
# INFO:canopy.load_study_job:Loading job index 316
# INFO:canopy.load_study_job:Loading job index 317
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 318
# INFO:canopy.load_study_job:Loading job index 319
# INFO:canopy.load_study_job:Loading job index 320
# INFO:canopy.load_study_job:Loading job index 321
# INFO:canopy.load_study_job:Loading job index 322
# INFO:canopy.load_study_job:Loading job index 323
# INFO:canopy.load_study_job:Loading job index 324
# INFO:canopy.load_study_job:Loading job index 325
# INFO:canopy.load_study_job:Loading job index 326
# INFO:canopy.load_study_job:Loading job index 327
# INFO:canopy.load_study_job:Loading job index 328
# INFO:canopy.load_study_job:Loading job index 329
# INFO:canopy.load_study_job:Loading job index 330
# INFO:canopy.load_study_job:Loading job index 331
# INFO:canopy.load_study_job:Loading job index 332
# INFO:canopy.load_study_job:Loading job index 333
# INFO:canopy.load_study_job:Loading job index 334
# INFO:canopy.load_study_job:Loading job index 335
# INFO:canopy.load_study_job:Loading job index 336
# INFO:canopy.load_study_job:Loading job index 337
# INFO:canopy.load_study_job:Loading job index 338
# INFO:canopy.load_study_job:Loading job index 339
# INFO:canopy.load_study_job:Loading job index 340
# INFO:canopy.load_study_job:Loading job index 341
# INFO:canopy.load_study_job:Loading job index 342
# INFO:canopy.load_study_job:Loading job index 343
# INFO:canopy.load_study_job:Loading job index 344
# INFO:canopy.load_study_job:Loading job index 345
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 346
# INFO:canopy.load_study_job:Loading job index 347
# INFO:canopy.load_study_job:Loading job index 348
# INFO:canopy.load_study_job:Loading job index 349
# INFO:canopy.load_study_job:Loading job index 350
# INFO:canopy.load_study_job:Loading job index 351
# INFO:canopy.load_study_job:Loading job index 352
# INFO:canopy.load_study_job:Loading job index 353
# INFO:canopy.load_study_job:Loading job index 354
# INFO:canopy.load_study_job:Loading job index 355
# INFO:canopy.load_study_job:Loading job index 356
# INFO:canopy.load_study_job:Loading job index 357
# INFO:canopy.load_study_job:Loading job index 358
# INFO:canopy.load_study_job:Loading job index 359
# INFO:canopy.load_study_job:Loading job index 360
# INFO:canopy.load_study_job:Loading job index 361
# INFO:canopy.load_study_job:Loading job index 362
# INFO:canopy.load_study_job:Loading job index 363
# INFO:canopy.load_study_job:Loading job index 364
# INFO:canopy.load_study_job:Loading job index 365
# INFO:canopy.load_study_job:Loading job index 366
# INFO:canopy.load_study_job:Loading job index 367
# INFO:canopy.load_study_job:Loading job index 368
# INFO:canopy.load_study_job:Loading job index 369
# INFO:canopy.load_study_job:Loading job index 370
# INFO:canopy.load_study_job:Loading job index 371
# INFO:canopy.load_study_job:Loading job index 372
# INFO:canopy.load_study_job:Loading job index 373
# INFO:canopy.load_study_job:Loading job index 374
# INFO:canopy.load_study_job:Loading job index 375
# INFO:canopy.load_study_job:Loading job index 376
# INFO:canopy.load_study_job:Loading job index 377
# INFO:canopy.load_study_job:Loading job index 378
# INFO:canopy.load_study_job:Loading job index 379
# INFO:canopy.load_study_job:Loading job index 380
# INFO:canopy.load_study_job:Loading job index 381
# INFO:canopy.load_study_job:Loading job index 382
# INFO:canopy.load_study_job:Loading job index 383
# INFO:canopy.load_study_job:Loading job index 384
# INFO:canopy.load_study_job:Loading job index 385
# INFO:canopy.load_study_job:Loading job index 386
# INFO:canopy.load_study_job:Loading job index 387
# INFO:canopy.load_study_job:Loading job index 388
# INFO:canopy.load_study_job:Loading job index 389
# INFO:canopy.load_study_job:Loading job index 390
# INFO:canopy.load_study_job:Loading job index 391
# INFO:canopy.load_study_job:Loading job index 392
# INFO:canopy.load_study_job:Loading job index 393
# INFO:canopy.load_study_job:Loading job index 394
# INFO:canopy.load_study_job:Loading job index 395
# INFO:canopy.load_study_job:Loading job index 396
# INFO:canopy.load_study_job:Loading job index 397
# INFO:canopy.load_study_job:Loading job index 398
# INFO:canopy.load_study_job:Loading job index 399
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 400
# INFO:canopy.load_study_job:Loading job index 401
# INFO:canopy.load_study_job:Loading job index 402
# INFO:canopy.load_study_job:Loading job index 403
# INFO:canopy.load_study_job:Loading job index 404
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 405
# INFO:canopy.load_study_job:Loading job index 406
# INFO:canopy.load_study_job:Loading job index 407
# INFO:canopy.load_study_job:Loading job index 408
# INFO:canopy.load_study_job:Loading job index 409
# INFO:canopy.load_study_job:Loading job index 410
# INFO:canopy.load_study_job:Loading job index 411
# INFO:canopy.load_study_job:Loading job index 412
# INFO:canopy.load_study_job:Loading job index 413
# INFO:canopy.load_study_job:Loading job index 414
# INFO:canopy.load_study_job:Loading job index 415
# INFO:canopy.load_study_job:Loading job index 416
# INFO:canopy.load_study_job:Loading job index 417
# INFO:canopy.load_study_job:Loading job index 418
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 419
# INFO:canopy.load_study_job:Loading job index 420
# INFO:canopy.load_study_job:Loading job index 421
# INFO:canopy.load_study_job:Loading job index 422
# INFO:canopy.load_study_job:Loading job index 423
# INFO:canopy.load_study_job:Loading job index 424
# INFO:canopy.load_study_job:Loading job index 425
# INFO:canopy.load_study_job:Loading job index 426
# INFO:canopy.load_study_job:Loading job index 427
# INFO:canopy.load_study_job:Loading job index 428
# INFO:canopy.load_study_job:Loading job index 429
# INFO:canopy.load_study_job:Loading job index 430
# INFO:canopy.load_study_job:Loading job index 431
# INFO:canopy.load_study_job:Loading job index 432
# INFO:canopy.load_study_job:Loading job index 433
# INFO:canopy.load_study_job:Loading job index 434
# INFO:canopy.load_study_job:Loading job index 435
# INFO:canopy.load_study_job:Loading job index 436
# INFO:canopy.load_study_job:Loading job index 437
# INFO:canopy.load_study_job:Loading job index 438
# INFO:canopy.load_study_job:Loading job index 439
# INFO:canopy.load_study_job:Loading job index 440
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 441
# INFO:canopy.load_study_job:Loading job index 442
# INFO:canopy.load_study_job:Loading job index 443
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 444
# INFO:canopy.load_study_job:Loading job index 445
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 446
# INFO:canopy.load_study_job:Loading job index 447
# INFO:canopy.load_study_job:Loading job index 448
# INFO:canopy.load_study_job:Loading job index 449
# INFO:canopy.load_study_job:Loading job index 450
# INFO:canopy.load_study_job:Loading job index 451
# INFO:canopy.load_study_job:Loading job index 452
# INFO:canopy.load_study_job:Loading job index 453
# INFO:canopy.load_study_job:Loading job index 454
# INFO:canopy.load_study_job:Loading job index 455
# INFO:canopy.load_study_job:Loading job index 456
# INFO:canopy.load_study_job:Loading job index 457
# INFO:canopy.load_study_job:Loading job index 458
# INFO:canopy.load_study_job:Loading job index 459
# INFO:canopy.load_study_job:Loading job index 460
# INFO:canopy.load_study_job:Loading job index 461
# INFO:canopy.load_study_job:Loading job index 462
# INFO:canopy.load_study_job:Loading job index 463
# INFO:canopy.load_study_job:Loading job index 464
# INFO:canopy.load_study_job:Loading job index 465
# INFO:canopy.load_study_job:Loading job index 466
# INFO:canopy.load_study_job:Loading job index 467
# INFO:canopy.load_study_job:Loading job index 468
# INFO:canopy.load_study_job:Loading job index 469
# INFO:canopy.load_study_job:Loading job index 470
# INFO:canopy.load_study_job:Loading job index 471
# INFO:canopy.load_study_job:Loading job index 472
# INFO:canopy.load_study_job:Loading job index 473
# INFO:canopy.load_study_job:Loading job index 474
# INFO:canopy.load_study_job:Loading job index 475
# INFO:canopy.load_study_job:Loading job index 476
# INFO:canopy.load_study_job:Loading job index 477
# INFO:canopy.load_study_job:Loading job index 478
# INFO:canopy.load_study_job:Loading job index 479
# INFO:canopy.load_study_job:Loading job index 480
# INFO:canopy.load_study_job:Loading job index 481
# INFO:canopy.load_study_job:Loading job index 482
# INFO:canopy.load_study_job:Loading job index 483
# INFO:canopy.load_study_job:Loading job index 484
# INFO:canopy.load_study_job:Loading job index 485
# INFO:canopy.load_study_job:Loading job index 486
# INFO:canopy.load_study_job:Loading job index 487
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 488
# INFO:canopy.load_study_job:Loading job index 489
# INFO:canopy.load_study_job:Loading job index 490
# INFO:canopy.load_study_job:Loading job index 491
# INFO:canopy.load_study_job:Loading job index 492
# INFO:canopy.load_study_job:Loading job index 493
# INFO:canopy.load_study_job:Loading job index 494
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 495
# INFO:canopy.load_study_job:Loading job index 496
# INFO:canopy.load_study_job:Loading job index 497
# INFO:canopy.load_study_job:Loading job index 498
# INFO:canopy.load_study_job:Loading job index 499
# INFO:canopy.load_study_job:Loading job index 500
# INFO:canopy.load_study_job:Loading job index 501
# INFO:canopy.load_study_job:Loading job index 502
# INFO:canopy.load_study_job:Loading job index 503
# INFO:canopy.load_study_job:Loading job index 504
# INFO:canopy.load_study_job:Loading job index 505
# INFO:canopy.load_study_job:Loading job index 506
# INFO:canopy.load_study_job:Loading job index 507
# INFO:canopy.load_study_job:Loading job index 508
# INFO:canopy.load_study_job:Loading job index 509
# INFO:canopy.load_study_job:Loading job index 510
# INFO:canopy.load_study_job:Loading job index 511
# INFO:canopy.load_study_job:Loading job index 512
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 513
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 514
# INFO:canopy.load_study_job:Loading job index 515
# INFO:canopy.load_study_job:Loading job index 516
# INFO:canopy.load_study_job:Loading job index 517
# INFO:canopy.load_study_job:Loading job index 518
# INFO:canopy.load_study_job:Loading job index 519
# INFO:canopy.load_study_job:Loading job index 520
# INFO:canopy.load_study_job:Loading job index 521
# INFO:canopy.load_study_job:Loading job index 522
# INFO:canopy.load_study_job:Loading job index 523
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 524
# INFO:canopy.load_study_job:Loading job index 525
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 526
# INFO:canopy.load_study_job:Loading job index 527
# INFO:canopy.load_study_job:Loading job index 528
# INFO:canopy.load_study_job:Loading job index 529
# INFO:canopy.load_study_job:Loading job index 530
# INFO:canopy.load_study_job:Loading job index 531
# INFO:canopy.load_study_job:Loading job index 532
# INFO:canopy.load_study_job:Loading job index 533
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 534
# INFO:canopy.load_study_job:Loading job index 535
# INFO:canopy.load_study_job:Loading job index 536
# INFO:canopy.load_study_job:Loading job index 537
# INFO:canopy.load_study_job:Loading job index 538
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 539
# INFO:canopy.load_study_job:Loading job index 540
# INFO:canopy.load_study_job:Loading job index 541
# INFO:canopy.load_study_job:Loading job index 542
# INFO:canopy.load_study_job:Loading job index 543
# INFO:canopy.load_study_job:Loading job index 544
# INFO:canopy.load_study_job:Loading job index 545
# INFO:canopy.load_study_job:Loading job index 546
# INFO:canopy.load_study_job:Loading job index 547
# INFO:canopy.load_study_job:Loading job index 548
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 549
# INFO:canopy.load_study_job:Loading job index 550
# INFO:canopy.load_study_job:Loading job index 551
# INFO:canopy.load_study_job:Loading job index 552
# INFO:canopy.load_study_job:Loading job index 553
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 554
# INFO:canopy.load_study_job:Loading job index 555
# INFO:canopy.load_study_job:Loading job index 556
# INFO:canopy.load_study_job:Loading job index 557
# INFO:canopy.load_study_job:Loading job index 558
# INFO:canopy.load_study_job:Loading job index 559
# INFO:canopy.load_study_job:Loading job index 560
# INFO:canopy.load_study_job:Loading job index 561
# INFO:canopy.load_study_job:Loading job index 562
# INFO:canopy.load_study_job:Loading job index 563
# INFO:canopy.load_study_job:Loading job index 564
# INFO:canopy.load_study_job:Loading job index 565
# INFO:canopy.load_study_job:Loading job index 566
# INFO:canopy.load_study_job:Loading job index 567
# INFO:canopy.load_study_job:Loading job index 568
# INFO:canopy.load_study_job:Loading job index 569
# INFO:canopy.load_study_job:Loading job index 570
# INFO:canopy.load_study_job:Loading job index 571
# INFO:canopy.load_study_job:Loading job index 572
# INFO:canopy.load_study_job:Loading job index 573
# INFO:canopy.load_study_job:Loading job index 574
# INFO:canopy.load_study_job:Loading job index 575
# INFO:canopy.load_study_job:Loading job index 576
# INFO:canopy.load_study_job:Loading job index 577
# INFO:canopy.load_study_job:Loading job index 578
# INFO:canopy.load_study_job:Loading job index 579
# INFO:canopy.load_study_job:Loading job index 580
# INFO:canopy.load_study_job:Loading job index 581
# INFO:canopy.load_study_job:Loading job index 582
# INFO:canopy.load_study_job:Loading job index 583
# INFO:canopy.load_study_job:Loading job index 584
# INFO:canopy.load_study_job:Loading job index 585
# INFO:canopy.load_study_job:Loading job index 586
# INFO:canopy.load_study_job:Loading job index 587
# INFO:canopy.load_study_job:Loading job index 588
# INFO:canopy.load_study_job:Loading job index 589
# INFO:canopy.load_study_job:Loading job index 590
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 591
# INFO:canopy.load_study_job:Loading job index 592
# INFO:canopy.load_study_job:Loading job index 593
# INFO:canopy.load_study_job:Loading job index 594
# INFO:canopy.load_study_job:Loading job index 595
# INFO:canopy.load_study_job:Loading job index 596
# INFO:canopy.load_study_job:Loading job index 597
# INFO:canopy.load_study_job:Loading job index 598
# INFO:canopy.load_study_job:Loading job index 599
# INFO:canopy.load_study_job:Loading job index 600
# INFO:canopy.load_study_job:Loading job index 601
# INFO:canopy.load_study_job:Loading job index 602
# INFO:canopy.load_study_job:Loading job index 603
# INFO:canopy.load_study_job:Loading job index 604
# INFO:canopy.load_study_job:Loading job index 605
# INFO:canopy.load_study_job:Loading job index 606
# INFO:canopy.load_study_job:Loading job index 607
# INFO:canopy.load_study_job:Loading job index 608
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 609
# INFO:canopy.load_study_job:Loading job index 610
# INFO:canopy.load_study_job:Loading job index 611
# INFO:canopy.load_study_job:Loading job index 612
# INFO:canopy.load_study_job:Loading job index 613
# INFO:canopy.load_study_job:Loading job index 614
# INFO:canopy.load_study_job:Loading job index 615
# INFO:canopy.load_study_job:Loading job index 616
# INFO:canopy.load_study_job:Loading job index 617
# INFO:canopy.load_study_job:Loading job index 618
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 619
# INFO:canopy.load_study_job:Loading job index 620
# INFO:canopy.load_study_job:Loading job index 621
# INFO:canopy.load_study_job:Loading job index 622
# INFO:canopy.load_study_job:Loading job index 623
# INFO:canopy.load_study_job:Loading job index 624
# INFO:canopy.load_study_job:Loading job index 625
# INFO:canopy.load_study_job:Loading job index 626
# INFO:canopy.load_study_job:Loading job index 627
# INFO:canopy.load_study_job:Loading job index 628
# INFO:canopy.load_study_job:Loading job index 629
# INFO:canopy.load_study_job:Loading job index 630
# INFO:canopy.load_study_job:Loading job index 631
# INFO:canopy.load_study_job:Loading job index 632
# INFO:canopy.load_study_job:Loading job index 633
# INFO:canopy.load_study_job:Loading job index 634
# INFO:canopy.load_study_job:Loading job index 635
# INFO:canopy.load_study_job:Loading job index 636
# INFO:canopy.load_study_job:Loading job index 637
# INFO:canopy.load_study_job:Loading job index 638
# INFO:canopy.load_study_job:Loading job index 639
# INFO:canopy.load_study_job:Loading job index 640
# INFO:canopy.load_study_job:Loading job index 641
# INFO:canopy.load_study_job:Loading job index 642
# INFO:canopy.load_study_job:Loading job index 643
# INFO:canopy.load_study_job:Loading job index 644
# INFO:canopy.load_study_job:Loading job index 645
# INFO:canopy.load_study_job:Loading job index 646
# INFO:canopy.load_study_job:Loading job index 647
# INFO:canopy.load_study_job:Loading job index 648
# INFO:canopy.load_study_job:Loading job index 649
# INFO:canopy.load_study_job:Loading job index 650
# INFO:canopy.load_study_job:Loading job index 651
# INFO:canopy.load_study_job:Loading job index 652
# INFO:canopy.load_study_job:Loading job index 653
# INFO:canopy.load_study_job:Loading job index 654
# INFO:canopy.load_study_job:Loading job index 655
# INFO:canopy.load_study_job:Loading job index 656
# INFO:canopy.load_study_job:Loading job index 657
# INFO:canopy.load_study_job:Loading job index 658
# INFO:canopy.load_study_job:Loading job index 659
# INFO:canopy.load_study_job:Loading job index 660
# INFO:canopy.load_study_job:Loading job index 661
# INFO:canopy.load_study_job:Loading job index 662
# INFO:canopy.load_study_job:Loading job index 663
# INFO:canopy.load_study_job:Loading job index 664
# INFO:canopy.load_study_job:Loading job index 665
# INFO:canopy.load_study_job:Loading job index 666
# INFO:canopy.load_study_job:Loading job index 667
# INFO:canopy.load_study_job:Loading job index 668
# INFO:canopy.load_study_job:Loading job index 669
# INFO:canopy.load_study_job:Loading job index 670
# INFO:canopy.load_study_job:Loading job index 671
# INFO:canopy.load_study_job:Loading job index 672
# INFO:canopy.load_study_job:Loading job index 673
# INFO:canopy.load_study_job:Loading job index 674
# INFO:canopy.load_study_job:Loading job index 675
# INFO:canopy.load_study_job:Loading job index 676
# INFO:canopy.load_study_job:Loading job index 677
# INFO:canopy.load_study_job:Loading job index 678
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 679
# INFO:canopy.load_study_job:Loading job index 680
# INFO:canopy.load_study_job:Loading job index 681
# INFO:canopy.load_study_job:Loading job index 682
# INFO:canopy.load_study_job:Loading job index 683
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 684
# INFO:canopy.load_study_job:Loading job index 685
# INFO:canopy.load_study_job:Loading job index 686
# INFO:canopy.load_study_job:Loading job index 687
# INFO:canopy.load_study_job:Loading job index 688
# INFO:canopy.load_study_job:Loading job index 689
# INFO:canopy.load_study_job:Loading job index 690
# INFO:canopy.load_study_job:Loading job index 691
# INFO:canopy.load_study_job:Loading job index 692
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 693
# INFO:canopy.load_study_job:Loading job index 694
# INFO:canopy.load_study_job:Loading job index 695
# INFO:canopy.load_study_job:Loading job index 696
# INFO:canopy.load_study_job:Loading job index 697
# INFO:canopy.load_study_job:Loading job index 698
# INFO:canopy.load_study_job:Loading job index 699
# INFO:canopy.load_study_job:Loading job index 700
# INFO:canopy.load_study_job:Loading job index 701
# INFO:canopy.load_study_job:Loading job index 702
# INFO:canopy.load_study_job:Loading job index 703
# INFO:canopy.load_study_job:Loading job index 704
# INFO:canopy.load_study_job:Loading job index 705
# INFO:canopy.load_study_job:Loading job index 706
# INFO:canopy.load_study_job:Loading job index 707
# INFO:canopy.load_study_job:Loading job index 708
# INFO:canopy.load_study_job:Loading job index 709
# INFO:canopy.load_study_job:Loading job index 710
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 711
# INFO:canopy.load_study_job:Loading job index 712
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 713
# INFO:canopy.load_study_job:Loading job index 714
# INFO:canopy.load_study_job:Loading job index 715
# INFO:canopy.load_study_job:Loading job index 716
# INFO:canopy.load_study_job:Loading job index 717
# INFO:canopy.load_study_job:Loading job index 718
# INFO:canopy.load_study_job:Loading job index 719
# INFO:canopy.load_study_job:Loading job index 720
# INFO:canopy.load_study_job:Loading job index 721
# INFO:canopy.load_study_job:Loading job index 722
# INFO:canopy.load_study_job:Loading job index 723
# INFO:canopy.load_study_job:Loading job index 724
# INFO:canopy.load_study_job:Loading job index 725
# INFO:canopy.load_study_job:Loading job index 726
# INFO:canopy.load_study_job:Loading job index 727
# INFO:canopy.load_study_job:Loading job index 728
# INFO:canopy.load_study_job:Loading job index 729
# INFO:canopy.load_study_job:Loading job index 730
# INFO:canopy.load_study_job:Loading job index 731
# INFO:canopy.load_study_job:Loading job index 732
# INFO:canopy.load_study_job:Loading job index 733
# INFO:canopy.load_study_job:Loading job index 734
# INFO:canopy.load_study_job:Loading job index 735
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 736
# INFO:canopy.load_study_job:Loading job index 737
# INFO:canopy.load_study_job:Loading job index 738
# INFO:canopy.load_study_job:Loading job index 739
# INFO:canopy.load_study_job:Loading job index 740
# INFO:canopy.load_study_job:Loading job index 741
# INFO:canopy.load_study_job:Loading job index 742
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 743
# ...
# INFO:canopy.load_study_job:Loading job index 838
# INFO:canopy.load_study_job:Loading job index 839
# INFO:canopy.load_study_job:Loading job index 840
# INFO:canopy.load_study_job:Loading job index 841
# INFO:canopy.load_study_job:Loading job index 842
# INFO:canopy.load_study_job:Loading job index 843
# INFO:canopy.load_study_job:Loading job index 844
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 845
# INFO:canopy.load_study_job:Loading job index 846
# INFO:canopy.load_study_job:Loading job index 847
# INFO:canopy.load_study_job:Loading job index 848
# INFO:canopy.load_study_job:Loading job index 849
# INFO:canopy.load_study_job:Loading job index 850
# INFO:canopy.load_study_job:Loading job index 851
# INFO:canopy.load_study_job:Loading job index 852
# INFO:canopy.load_study_job:Loading job index 853
# INFO:canopy.load_study_job:Loading job index 854
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 855
# INFO:canopy.load_study_job:Loading job index 856
# INFO:canopy.load_study_job:Loading job index 857
# INFO:canopy.load_study_job:Loading job index 858
# INFO:canopy.load_study_job:Loading job index 859
# INFO:canopy.load_study_job:Loading job index 860
# INFO:canopy.load_study_job:Loading job index 861
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 862
# INFO:canopy.load_study_job:Loading job index 863
# INFO:canopy.load_study_job:Loading job index 864
# INFO:canopy.load_study_job:Loading job index 865
# INFO:canopy.load_study_job:Loading job index 866
# INFO:canopy.load_study_job:Loading job index 867
# INFO:canopy.load_study_job:Loading job index 868
# INFO:canopy.load_study_job:Loading job index 869
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 870
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 871
# INFO:canopy.load_study_job:Loading job index 872
# INFO:canopy.load_study_job:Loading job index 873
# INFO:canopy.load_study_job:Loading job index 874
# INFO:canopy.load_study_job:Loading job index 875
# INFO:canopy.load_study_job:Loading job index 876
# INFO:canopy.load_study_job:Loading job index 877
# INFO:canopy.load_study_job:Loading job index 878
# INFO:canopy.load_study_job:Loading job index 879
# INFO:canopy.load_study_job:Loading job index 880
# INFO:canopy.load_study_job:Loading job index 881
# INFO:canopy.load_study_job:Loading job index 882
# INFO:canopy.load_study_job:Loading job index 883
# INFO:canopy.load_study_job:Loading job index 884
# INFO:canopy.load_study_job:Loading job index 885
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 886
# INFO:canopy.load_study_job:Loading job index 887
# INFO:canopy.load_study_job:Loading job index 888
# INFO:canopy.load_study_job:Loading job index 889
# INFO:canopy.load_study_job:Loading job index 890
# INFO:canopy.load_study_job:Loading job index 891
# INFO:canopy.load_study_job:Loading job index 892
# INFO:canopy.load_study_job:Loading job index 893
# INFO:canopy.load_study_job:Loading job index 894
# INFO:canopy.load_study_job:Loading job index 895
# INFO:canopy.load_study_job:Loading job index 896
# INFO:canopy.load_study_job:Loading job index 897
# INFO:canopy.load_study_job:Loading job index 898
# INFO:canopy.load_study_job:Loading job index 899
# INFO:canopy.load_study_job:Loading job index 900
# INFO:canopy.load_study_job:Loading job index 901
# INFO:canopy.load_study_job:Loading job index 902
# INFO:canopy.load_study_job:Loading job index 903
# INFO:canopy.load_study_job:Loading job index 904
# INFO:canopy.load_study_job:Loading job index 905
# INFO:canopy.load_study_job:Loading job index 906
# INFO:canopy.load_study_job:Loading job index 907
# INFO:canopy.load_study_job:Loading job index 908
# INFO:canopy.load_study_job:Loading job index 909
# INFO:canopy.load_study_job:Loading job index 910
# INFO:canopy.load_study_job:Loading job index 911
# INFO:canopy.load_study_job:Loading job index 912
# INFO:canopy.load_study_job:Loading job index 913
# INFO:canopy.load_study_job:Loading job index 914
# INFO:canopy.load_study_job:Loading job index 915
# INFO:canopy.load_study_job:Loading job index 916
# INFO:canopy.load_study_job:Loading job index 917
# INFO:canopy.load_study_job:Loading job index 918
# INFO:canopy.load_study_job:Loading job index 919
# INFO:canopy.load_study_job:Loading job index 920
# INFO:canopy.load_study_job:Loading job index 921
# INFO:canopy.load_study_job:Loading job index 922
# INFO:canopy.load_study_job:Loading job index 923
# INFO:canopy.load_study_job:Loading job index 924
# INFO:canopy.load_study_job:Loading job index 925
# INFO:canopy.load_study_job:Loading job index 926
# INFO:canopy.load_study_job:Loading job index 927
# INFO:canopy.load_study_job:Loading job index 928
# INFO:canopy.load_study_job:Loading job index 929
# INFO:canopy.load_study_job:Loading job index 930
# INFO:canopy.load_study_job:Loading job index 931
# INFO:canopy.load_study_job:Loading job index 932
# INFO:canopy.load_study_job:Loading job index 933
# INFO:canopy.load_study_job:Loading job index 934
# INFO:canopy.load_study_job:Loading job index 935
# INFO:canopy.load_study_job:Loading job index 936
# INFO:canopy.load_study_job:Loading job index 937
# INFO:canopy.load_study_job:Loading job index 938
# INFO:canopy.load_study_job:Loading job index 939
# INFO:canopy.load_study_job:Loading job index 940
# INFO:canopy.load_study_job:Loading job index 941
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 942
# INFO:canopy.load_study_job:Loading job index 943
# INFO:canopy.load_study_job:Loading job index 944
# INFO:canopy.load_study_job:Loading job index 945
# INFO:canopy.load_study_job:Loading job index 946
# INFO:canopy.load_study_job:Loading job index 947
# INFO:canopy.load_study_job:Loading job index 948
# INFO:canopy.load_study_job:Loading job index 949
# INFO:canopy.load_study_job:Loading job index 950
# INFO:canopy.load_study_job:Loading job index 951
# INFO:canopy.load_study_job:Loading job index 952
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 953
# INFO:canopy.load_study_job:Loading job index 954
# INFO:canopy.load_study_job:Loading job index 955
# INFO:canopy.load_study_job:Loading job index 956
# INFO:canopy.load_study_job:Loading job index 957
# INFO:canopy.load_study_job:Loading job index 958
# INFO:canopy.load_study_job:Loading job index 959
# INFO:canopy.load_study_job:Loading job index 960
# INFO:canopy.load_study_job:Loading job index 961
# INFO:canopy.load_study_job:Loading job index 962
# INFO:canopy.load_study_job:Loading job index 963
# INFO:canopy.load_study_job:Loading job index 964
# INFO:canopy.load_study_job:Loading job index 965
# INFO:canopy.load_study_job:Loading job index 966
# INFO:canopy.load_study_job:Loading job index 967
# INFO:canopy.load_study_job:Loading job index 968
# INFO:canopy.load_study_job:Loading job index 969
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_VectorMetadata.csv (The specified blob does not exist.)
# WARNING:canopy.request_with_retry:Response error loading DynamicLap_ScalarResults.csv (The specified blob does not exist.)
# INFO:canopy.load_study_job:Loading job index 970
# INFO:canopy.load_study_job:Loading job index 971
# INFO:canopy.load_study_job:Loading job index 972
# INFO:canopy.load_study_job:Loading job index 973
# INFO:canopy.load_study_job:Loading job index 974
# INFO:canopy.load_study_job:Loading job index 975
# INFO:canopy.load_study_job:Loading job index 976
# INFO:canopy.load_study_job:Loading job index 977
# INFO:canopy.load_study_job:Loading job index 978
# INFO:canopy.load_study_job:Loading job index 979
# INFO:canopy.load_study_job:Loading job index 980
# INFO:canopy.load_study_job:Loading job index 981
# INFO:canopy.load_study_job:Loading job index 982
# INFO:canopy.load_study_job:Loading job index 983
# INFO:canopy.load_study_job:Loading job index 984
# INFO:canopy.load_study_job:Loading job index 985
# INFO:canopy.load_study_job:Loading job index 986
# INFO:canopy.load_study_job:Loading job index 987
# INFO:canopy.load_study_job:Loading job index 988
# INFO:canopy.load_study_job:Loading job index 989
# INFO:canopy.load_study_job:Loading job index 990
# INFO:canopy.load_study_job:Loading job index 991
# INFO:canopy.load_study_job:Loading job index 992
# INFO:canopy.load_study_job:Loading job index 993
# INFO:canopy.load_study_job:Loading job index 994
# INFO:canopy.load_study_job:Loading job index 995
# INFO:canopy.load_study_job:Loading job index 996
# INFO:canopy.load_study_job:Loading job index 997
# INFO:canopy.load_study_job:Loading job index 998
# INFO:canopy.load_study_job:Loading job index 999
# Checking job 48fda98fb8a44663b831df56272bb99f-0 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-23 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-64 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-85 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-106 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-107 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-121 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-159 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-169 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-174 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-208 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-214 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-226 for scalar tLapTotal...
# Job ID: 48fda98fb8a44663b831df56272bb99f-226, Scalar Value: 77.172144
# Checking job 48fda98fb8a44663b831df56272bb99f-256 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-271 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-273 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-289 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-290 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-299 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-316 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-344 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-397 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-403 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-411 for scalar tLapTotal...
# Job ID: 48fda98fb8a44663b831df56272bb99f-411, Scalar Value: 76.953533
# Checking job 48fda98fb8a44663b831df56272bb99f-417 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-439 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-442 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-445 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-485 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-486 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-493 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-510 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-521 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-524 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-532 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-538 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-546 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-551 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-588 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-604 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-616 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-677 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-681 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-692 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-709 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-711 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-712 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-735 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-741 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-750 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-765 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-768 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-777 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-799 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-809 for scalar tLapTotal...
# Job ID: 48fda98fb8a44663b831df56272bb99f-809, Scalar Value: 77.051247
# Checking job 48fda98fb8a44663b831df56272bb99f-817 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-819 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-822 for scalar tLapTotal...
# Job ID: 48fda98fb8a44663b831df56272bb99f-822, Scalar Value: 77.013219
# Checking job 48fda98fb8a44663b831df56272bb99f-823 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-828 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-835 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-844 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-853 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-854 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-861 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-868 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-870 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-884 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-940 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-951 for scalar tLapTotal...
# Checking job 48fda98fb8a44663b831df56272bb99f-966 for scalar tLapTotal...
# ('48fda98fb8a44663b831df56272bb99f-411', 76.953533)

# %% [markdown]
# # Found one!
#
# Woop woop, looks like I found a faster 'legal' car here!
#
# ![alt text](images/RaceEngChallenge/image-10.png)
#
# And that's it, hope this tutorial was helpful to demonstrate this iterative process.
